# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From C:\Users\schmi\Anaconda3\envs\dlnd\lib\site-packages\tensorflow\python\ops\nn_impl.py:1310: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6605 0.0312 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6553 0.0265 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5030 0.0263 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6532 0.0263 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5185 0.0265 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5056 0.0263 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5697 0.0264 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5408 0.0269 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4691 0.0286 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4325 0.0266 sec/batch
# Nearest to only: kilns, paradis, circulatory, tactical, hornby, zone, demonstrably, eukaryotic,
# Nearest to to: subculture, cookie, scully, georgians, orthodoxy, berber, sanj, uninterested,
# Nearest to also: ayling, bretagne, kilgore, facilitate, ridgway, mona, cee, satsuki,
# Nearest to s: christopher, vytautas, goldwyn, interlisp, sfsr, shirov, forti, like,
# Nearest to time: hudd, ibelin, incorrect, balochi, lulach, installations, pronounced, kilometres,
# Nearest to of: fulgencio, ochre, phallic, lawrence, ellsworth, sidelines, adequacy, enacted,
# Nearest to been: orthographic, handedly, philanthropists, adventist, f, chalcedonian, dyes, icct,
# Nearest to have: herrera, farce, vincendeau, prices, style, macanese, mau, antennas,
# Nearest to units: signor, terminally, beli, populist, steeper, enlai, wondrous, uptime,
# Nearest to question: lumber, gadolinite, affine, workgroups, gennadius, otp, pergamon, murderer,
# Nearest to marriage: helmstedt, bermuda, ocular, lahaye, av, guarantee, kryptonians, manus,
# Nearest to accepted: reconquering, bulgarians, michio, tartaglia, horton, soap, romanians, excessively,
# Nearest to ocean: trucial, terming, marley, cholesterol, northumberland, confederates, soils, guatemala,
# Nearest to existence: aliasing, nleutnant, inquire, boarder, riebeeck, exuberance, ailey, golding,
# Nearest to cost: sally, signage, ken, uniform, ghostly, cegep, cena, grammarians,
# Nearest to applied: mancini, tabloids, sylvian, outweighs, susceptibility, linear, plunge, ricardo,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4837 0.0275 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3624 0.0266 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3576 0.0264 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2402 0.0271 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1869 0.0269 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1588 0.0264 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1339 0.0264 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0685 0.0266 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0042 0.0264 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0017 0.0264 sec/batch
# Nearest to only: tactical, zone, of, complex, kilns, common, consist, sandwiched,
# Nearest to to: subculture, cookie, faces, orthodoxy, measurable, file, warrant, dominican,
# Nearest to also: facilitate, give, ayling, southwest, jr, justified, collapsed, bretagne,
# Nearest to s: christopher, like, vytautas, high, goldwyn, incense, sfsr, illumination,
# Nearest to time: incorrect, pronounced, restricts, kilometres, into, plata, balochi, installations,
# Nearest to of: enacted, fulgencio, themselves, consist, lawrence, only, heavy, tendency,
# Nearest to been: f, orthographic, seems, super, dyes, minute, adventist, chalcedonian,
# Nearest to have: herrera, farce, prices, style, quantum, sagittarius, specifically, status,
# Nearest to units: populist, signor, highly, terminally, why, enlai, beli, eager,
# Nearest to question: lumber, inconsistent, workgroups, gadolinite, pergamon, clubs, developed, preventing,
# Nearest to marriage: helmstedt, guarantee, overthrown, lahaye, av, substances, myths, interim,
# Nearest to accepted: hindrance, bertold, psychiatric, interesting, reconquering, tangent, horton, excessively,
# Nearest to ocean: trucial, marley, ghana, theorem, terming, cholesterol, northumberland, printed,
# Nearest to existence: inquire, nleutnant, aliasing, rejected, boarder, outline, are, hated,
# Nearest to cost: uniform, sally, ken, signage, grammarians, weekend, appear, flagship,
# Nearest to applied: linear, mancini, ricardo, ancestry, fact, susceptibility, rejected, artist,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9385 0.0271 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9313 0.0263 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8895 0.0263 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8646 0.0264 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8134 0.0264 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8157 0.0264 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7835 0.0265 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8041 0.0264 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7777 0.0264 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7936 0.0269 sec/batch
# Nearest to only: complex, tactical, zone, gutenberg, circulatory, kilns, eukaryotic, generosity,
# Nearest to to: subculture, orthodoxy, cookie, faces, warrant, scully, diagram, measurable,
# Nearest to also: facilitate, bretagne, mercantile, give, jr, brands, ayling, volvo,
# Nearest to s: christopher, goldwyn, vytautas, incense, illumination, flames, objectification, forti,
# Nearest to time: incorrect, kilometres, installations, telescope, pronounced, astonishing, restricts, hudd,
# Nearest to of: themselves, fulgencio, individuality, updated, lawrence, sidelines, physicists, enacted,
# Nearest to been: orthographic, super, chalcedonian, dyes, f, pedal, devout, failed,
# Nearest to have: herrera, farce, prices, travel, spins, suppression, specifically, style,
# Nearest to units: signor, populist, eager, beli, highly, terminally, steeper, wondrous,
# Nearest to question: lumber, gadolinite, workgroups, pergamon, inconsistent, clubs, privileges, preventing,
# Nearest to marriage: helmstedt, guarantee, interim, immoral, lahaye, myths, av, overthrown,
# Nearest to accepted: tartaglia, horton, bertold, reconquering, hindrance, guises, soap, psychiatric,
# Nearest to ocean: trucial, marley, ghana, fiscal, gatling, northumberland, soils, guatemala,
# Nearest to existence: nleutnant, outline, inquire, aliasing, boarder, rejected, selective, aristocratic,
# Nearest to cost: sally, uniform, ken, signage, grammarians, necklace, weekend, patronage,
# Nearest to applied: mancini, linear, declare, tabloids, susceptibility, fact, artist, equation,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7692 0.0276 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7527 0.0267 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7342 0.0266 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7053 0.0267 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7159 0.0271 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6995 0.0266 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6994 0.0264 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7419 0.0264 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7334 0.0264 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6891 0.0265 sec/batch
# Nearest to only: complex, circulatory, kilns, tactical, zone, ming, demonstrably, generosity,
# Nearest to to: subculture, orthodoxy, diagram, cookie, scully, warrant, rolls, faces,
# Nearest to also: facilitate, bretagne, mercantile, kilgore, ridgway, ayling, brands, mona,
# Nearest to s: christopher, vytautas, goldwyn, interlisp, sfsr, objectification, illumination, forti,
# Nearest to time: incorrect, kilometres, balochi, hudd, astonishing, ibelin, installations, pronounced,
# Nearest to of: fulgencio, themselves, individuality, reinvent, commandments, adequacy, igneous, lawrence,
# Nearest to been: orthographic, chalcedonian, ww, ragtime, super, dyes, handedly, normative,
# Nearest to have: herrera, farce, spins, travel, suppression, lagrange, prices, specifically,
# Nearest to units: signor, steeper, populist, beli, eager, terminally, wondrous, appl,
# Nearest to question: lumber, pergamon, inconsistent, gadolinite, workgroups, privileges, otp, jacobi,
# Nearest to marriage: helmstedt, immoral, lahaye, interim, ocular, av, myths, cw,
# Nearest to accepted: bulgarians, bertold, playable, tartaglia, reconquering, horton, michio, guises,
# Nearest to ocean: trucial, marley, ghana, gatling, artefacts, cholesterol, northumberland, soils,
# Nearest to existence: nleutnant, boarder, aliasing, inquire, outline, rejected, aristocratic, ailey,
# Nearest to cost: sally, signage, uniform, ken, grammarians, necklace, grenade, egbert,
# Nearest to applied: mancini, linear, susceptibility, tabloids, outweighs, fact, declare, ricardo,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6756 0.0271 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6738 0.0264 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6029 0.0267 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6011 0.0264 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6382 0.0264 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6088 0.0264 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6120 0.0195 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5277 0.0265 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5137 0.0265 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4802 0.0264 sec/batch
# Nearest to only: complex, circulatory, kilns, eukaryotic, zone, tactical, generosity, waveguide,
# Nearest to to: subculture, cookie, orthodoxy, diagram, measurable, precedent, scully, rolls,
# Nearest to also: facilitate, bretagne, kilgore, ridgway, mercantile, ayling, brands, features,
# Nearest to s: christopher, vytautas, objectification, sfsr, goldwyn, unsystematic, interlisp, walks,
# Nearest to time: incorrect, balochi, hudd, kilometres, ibelin, astonishing, isotopic, restricts,
# Nearest to of: fulgencio, themselves, legged, commandments, ellsworth, adequacy, reinvent, lawrence,
# Nearest to been: chalcedonian, orthographic, ww, ragtime, pedal, cortes, haze, decades,
# Nearest to have: herrera, spins, farce, suppression, oxidative, macanese, vincendeau, specifically,
# Nearest to units: signor, steeper, beli, icd, taney, populist, appl, eager,
# Nearest to question: lumber, inconsistent, workgroups, gadolinite, pergamon, privileges, affine, otp,
# Nearest to marriage: helmstedt, lahaye, immoral, cw, ocular, manus, tibeto, av,
# Nearest to accepted: reconquering, bulgarians, bertold, michio, playable, horton, tartaglia, guises,
# Nearest to ocean: trucial, ghana, marley, artefacts, cholesterol, north, northumberland, soils,
# Nearest to existence: nleutnant, aliasing, boarder, inquire, outline, rejected, optimizing, ailey,
# Nearest to cost: sally, necklace, uniform, grammarians, grenade, signage, zimmerman, rna,
# Nearest to applied: linear, susceptibility, fact, outweighs, tabloids, mancini, equation, screws,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5070 0.0273 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4866 0.0264 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4393 0.0265 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5105 0.0264 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4779 0.0265 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4953 0.0263 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4700 0.0264 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3883 0.0264 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4469 0.0264 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4124 0.0264 sec/batch
# Nearest to only: complex, circulatory, kilns, eukaryotic, tactical, seam, hornby, mixtec,
# Nearest to to: subculture, measurable, orthodoxy, diagram, refugee, rolls, scully, cookie,
# Nearest to also: bretagne, facilitate, kilgore, ridgway, give, ayling, volvo, nebulous,
# Nearest to s: christopher, vytautas, sfsr, unsystematic, objectification, interlisp, goldwyn, walks,
# Nearest to time: incorrect, hudd, tunnel, balochi, kilometres, astonishing, pronounced, jazeera,
# Nearest to of: legged, adequacy, themselves, fulgencio, lawrence, reinvent, enacted, commandments,
# Nearest to been: chalcedonian, orthographic, ww, ragtime, minutemen, cortes, disappointing, decades,
# Nearest to have: spins, herrera, farce, vincendeau, specifically, oxidative, qualitative, prices,
# Nearest to units: steeper, signor, icd, taney, rodham, frequencies, appl, highly,
# Nearest to question: inconsistent, lumber, workgroups, pergamon, gadolinite, privileges, valued, blasphemy,
# Nearest to marriage: helmstedt, immoral, lahaye, cw, manus, av, ocular, tibeto,
# Nearest to accepted: reconquering, playable, bulgarians, michio, bertold, null, tartaglia, hindrance,
# Nearest to ocean: trucial, ghana, artefacts, soils, north, marley, cholesterol, northumberland,
# Nearest to existence: nleutnant, inquire, outline, aliasing, rejected, boarder, optimizing, diddy,
# Nearest to cost: sally, uniform, necklace, grenade, grammarians, zimmerman, signage, pinnipeds,
# Nearest to applied: linear, tabloids, fact, susceptibility, outweighs, seawater, multipliers, screws,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4668 0.0274 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4145 0.0263 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4358 0.0263 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4181 0.0263 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3922 0.0263 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4553 0.0265 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3967 0.0263 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3546 0.0264 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4174 0.0264 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3859 0.0265 sec/batch
# Nearest to only: complex, circulatory, kilns, hornby, mixtec, tactical, seam, quantitative,
# Nearest to to: subculture, measurable, orthodoxy, refugee, scully, warrant, necessary, faces,
# Nearest to also: bretagne, facilitate, kilgore, rearranged, features, ridgway, ayling, give,
# Nearest to s: christopher, sfsr, unsystematic, objectification, goldwyn, forti, vytautas, interlisp,
# Nearest to time: incorrect, hudd, balochi, tunnel, astonishing, kilometres, unmolested, pippen,
# Nearest to of: adequacy, themselves, fulgencio, commandments, lawrence, legged, tendency, mongoloid,
# Nearest to been: chalcedonian, orthographic, ragtime, pedal, disappointing, contraception, cortes, dampier,
# Nearest to have: spins, herrera, farce, vincendeau, suppression, specifically, init, annul,
# Nearest to units: steeper, signor, frequencies, icd, rodham, taney, appl, whirl,
# Nearest to question: inconsistent, blasphemy, philosophers, valued, workgroups, privileges, lumber, pergamon,
# Nearest to marriage: helmstedt, immoral, lahaye, cw, manus, interim, av, myths,
# Nearest to accepted: reconquering, playable, null, bulgarians, excessively, michio, tartaglia, bertold,
# Nearest to ocean: ghana, trucial, soils, north, artefacts, marley, faroe, guatemala,
# Nearest to existence: nleutnant, rejected, outline, inquire, beliefs, boarder, aliasing, diddy,
# Nearest to cost: sally, uniform, grenade, necklace, pinnipeds, grammarians, rna, signage,
# Nearest to applied: linear, fact, susceptibility, outweighs, seawater, tabloids, propagates, screws,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3609 0.0271 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4052 0.0263 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3564 0.0264 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3623 0.0266 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4188 0.0264 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3900 0.0266 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4052 0.0265 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3549 0.0265 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3089 0.0264 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3586 0.0263 sec/batch
# Nearest to only: circulatory, complex, generosity, kilns, zone, seam, mixtec, tactical,
# Nearest to to: refugee, orthodoxy, subculture, measurable, effecting, necessary, warrant, precedent,
# Nearest to also: bretagne, facilitate, kilgore, features, rearranged, brassiere, nebulous, ridgway,
# Nearest to s: christopher, sfsr, unsystematic, objectification, goldwyn, forti, hewlett, denounce,
# Nearest to time: hudd, incorrect, donating, balochi, kilometres, astonishing, rotherhithe, tunnel,
# Nearest to of: themselves, mongoloid, forty, enacted, legged, absolutism, fulgencio, iberian,
# Nearest to been: chalcedonian, orthographic, ragtime, contraception, decades, dampier, create, parris,
# Nearest to have: spins, herrera, farce, suppression, specifically, vincendeau, certain, immediately,
# Nearest to units: steeper, signor, frequencies, appl, icd, taney, zero, rodham,
# Nearest to question: inconsistent, blasphemy, valued, privileges, philosophers, jacobi, workgroups, pergamon,
# Nearest to marriage: helmstedt, immoral, lahaye, manus, cw, sunglasses, interim, slaying,
# Nearest to accepted: reconquering, bulgarians, null, michio, bertold, apparently, cosmos, lingering,
# Nearest to ocean: ghana, soils, trucial, artefacts, islands, marley, cholesterol, faroe,
# Nearest to existence: rejected, nleutnant, inquire, beliefs, boarder, christ, outline, aliasing,
# Nearest to cost: sally, uniform, grenade, rated, necklace, valuables, pinnipeds, zimmerman,
# Nearest to applied: fact, susceptibility, linear, declare, seawater, zuse, rejected, inoffensive,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3417 0.0272 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3272 0.0268 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3693 0.0271 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3752 0.0269 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3942 0.0269 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2590 0.0266 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2969 0.0265 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3717 0.0264 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2414 0.0265 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2874 0.0268 sec/batch
# Nearest to only: circulatory, complex, hornby, zone, kilns, seam, tactical, generosity,
# Nearest to to: refugee, measurable, abuser, orthodoxy, subculture, ignores, precedent, faces,
# Nearest to also: bretagne, facilitate, ridgway, kilgore, features, mona, give, nebulous,
# Nearest to s: christopher, sfsr, unsystematic, goldwyn, objectification, vytautas, bachelors, denounce,
# Nearest to time: hudd, incorrect, donating, balochi, viz, tunnel, astonishing, rotherhithe,
# Nearest to of: forty, fulgencio, absolutism, lawrence, sander, ancien, unify, mongoloid,
# Nearest to been: chalcedonian, orthographic, create, contraception, parris, ragtime, decades, dampier,
# Nearest to have: spins, farce, herrera, specifically, certain, vincendeau, suppression, highbury,
# Nearest to units: steeper, signor, frequencies, icd, appl, taney, rodham, nonmetals,
# Nearest to question: inconsistent, blasphemy, valued, privileges, jacobi, pergamon, affine, philosophers,
# Nearest to marriage: immoral, helmstedt, manus, lahaye, cw, slaying, sunglasses, cultures,
# Nearest to accepted: bulgarians, reconquering, michio, bertold, qpl, null, cosmos, apparently,
# Nearest to ocean: ghana, soils, islands, artefacts, cholesterol, trucial, faroe, guatemala,
# Nearest to existence: rejected, nleutnant, inquire, beliefs, albinism, intentions, aristocratic, boarder,
# Nearest to cost: uniform, sally, grenade, valuables, portable, rated, necklace, proprietary,
# Nearest to applied: rejected, fact, sylvian, zuse, frankenheimer, susceptibility, declare, inoffensive,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2835 0.0274 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3123 0.0267 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3412 0.0120 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2629 0.0270 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2331 0.0268 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2154 0.0270 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2368 0.0269 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2087 0.0265 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2277 0.0266 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1671 0.0273 sec/batch
# Nearest to only: circulatory, zone, complex, justly, seam, thoracic, hornby, kilns,
# Nearest to to: refugee, subculture, shoot, measurable, precedent, ignores, abuser, contraceptives,
# Nearest to also: bretagne, facilitate, ridgway, features, mona, brands, eunuchs, nebulous,
# Nearest to s: christopher, sfsr, goldwyn, unsystematic, objectification, hewlett, vytautas, interlisp,
# Nearest to time: hudd, donating, viz, unmolested, kilometres, incorrect, ibelin, balochi,
# Nearest to of: forty, glick, yerkes, important, legged, masovia, unify, ancien,
# Nearest to been: chalcedonian, create, absorbs, decades, capelli, parris, orthographic, ragtime,
# Nearest to have: farce, spins, herrera, certain, specifically, vincendeau, macanese, init,
# Nearest to units: steeper, signor, zero, frequencies, icd, appl, taney, wageningen,
# Nearest to question: inconsistent, blasphemy, valued, affine, workgroups, subseteq, gadolinite, jacobi,
# Nearest to marriage: immoral, helmstedt, lahaye, manus, cw, slaying, pyrrhus, disgust,
# Nearest to accepted: reconquering, bulgarians, michio, cosmos, null, bertold, qpl, essences,
# Nearest to ocean: soils, cholesterol, ghana, islands, trucial, faroe, artefacts, guatemala,
# Nearest to existence: nleutnant, rejected, inquire, albinism, proofs, impinging, outline, aliasing,
# Nearest to cost: uniform, sally, rated, valuables, grenade, portable, market, proprietary,
# Nearest to applied: zuse, sylvian, frankenheimer, susceptibility, rejected, linear, tabloids, fact,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2479 0.0276 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2121 0.0271 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2233 0.0271 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1524 0.0266 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1753 0.0267 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1509 0.0268 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1871 0.0276 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1461 0.0281 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2076 0.0266 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1797 0.0284 sec/batch
# Nearest to only: circulatory, hornby, seam, complex, thoracic, justly, booms, mixtec,
# Nearest to to: execute, subculture, necessary, that, refugee, not, shoot, precedent,
# Nearest to also: bretagne, facilitate, ridgway, nebulous, give, brands, features, brassiere,
# Nearest to s: christopher, sfsr, goldwyn, objectification, hewlett, unsystematic, bachelors, ust,
# Nearest to time: hudd, donating, incorrect, unmolested, viz, into, tunnel, astonishing,
# Nearest to of: lawrence, important, has, forty, legged, absolutism, yerkes, a,
# Nearest to been: orthographic, create, decades, absorbs, chalcedonian, dampier, parris, meridians,
# Nearest to have: spins, farce, herrera, couples, specifically, vincendeau, certain, ayn,
# Nearest to units: steeper, signor, appl, frequencies, taney, icd, nonmetals, angelique,
# Nearest to question: inconsistent, valued, blasphemy, philosophers, jacobi, workgroups, affine, subseteq,
# Nearest to marriage: immoral, helmstedt, lahaye, manus, cw, eighteen, slaying, rejected,
# Nearest to accepted: reconquering, bulgarians, michio, null, bertold, qpl, cosmos, lingering,
# Nearest to ocean: soils, cholesterol, islands, faroe, ghana, trucial, guatemala, mariana,
# Nearest to existence: nleutnant, albinism, rejected, inquire, impinging, outline, intentions, proofs,
# Nearest to cost: sally, uniform, rated, portable, proprietary, grenade, valuables, minix,
# Nearest to applied: zuse, frankenheimer, sylvian, seawater, fact, linear, tabloids, susceptibility,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1679 0.0283 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2168 0.0266 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1732 0.0264 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1698 0.0265 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1832 0.0279 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2011 0.0265 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1864 0.0267 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1379 0.0289 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1241 0.0297 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1639 0.0296 sec/batch
# Nearest to only: complex, hornby, circulatory, justly, be, thus, booms, thoracic,
# Nearest to to: that, refugee, measurable, not, subculture, necessary, ecb, execute,
# Nearest to also: facilitate, bretagne, ridgway, give, nebulous, features, mona, substitution,
# Nearest to s: christopher, sfsr, goldwyn, hewlett, unsystematic, forti, objectification, ict,
# Nearest to time: hudd, donating, incorrect, mazes, unmolested, viz, astonishing, into,
# Nearest to of: forty, ancien, lawrence, important, a, evanston, eight, absolutism,
# Nearest to been: create, orthographic, absorbs, parris, troubadors, lgbt, decades, contraception,
# Nearest to have: spins, farce, herrera, specifically, couples, vincendeau, oxidative, immemorial,
# Nearest to units: signor, steeper, appl, frequencies, nonmetals, predicts, icd, angelique,
# Nearest to question: inconsistent, valued, blasphemy, philosophers, workgroups, privileges, poli, jacobi,
# Nearest to marriage: immoral, helmstedt, lahaye, manus, slaying, cw, abduction, eighteen,
# Nearest to accepted: reconquering, bulgarians, null, bertold, qpl, essences, lingering, cosmos,
# Nearest to ocean: soils, ghana, islands, mariana, faroe, cholesterol, artefacts, trucial,
# Nearest to existence: albinism, rejected, nleutnant, inquire, intentions, impinging, theories, proofs,
# Nearest to cost: sally, investors, uniform, rated, valuables, proprietary, portable, grenade,
# Nearest to applied: rejected, frankenheimer, zuse, fact, notions, susceptibility, sylvian, declare,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1869 0.0286 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1706 0.0270 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1861 0.0265 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1710 0.0272 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1258 0.0264 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1093 0.0265 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1688 0.0265 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1345 0.0278 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2014 0.0278 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2119 0.0269 sec/batch
# Nearest to only: thus, centrist, circulatory, seam, hornby, zone, mixtec, thoracic,
# Nearest to to: that, refugee, ecb, before, investiture, in, precedent, warrant,
# Nearest to also: ridgway, mona, facilitate, bretagne, give, discussing, nebulous, features,
# Nearest to s: christopher, sfsr, goldwyn, hewlett, objectification, unsystematic, forti, bachelors,
# Nearest to time: hudd, donating, astonishing, viz, rotherhithe, mazes, ibelin, unmolested,
# Nearest to of: the, eight, evanston, rector, ancien, forty, lawrence, a,
# Nearest to been: create, decades, lgbt, parris, troubadors, absorbs, moloch, dampier,
# Nearest to have: farce, herrera, spins, couples, confucians, specifically, vincendeau, ayn,
# Nearest to units: signor, appl, steeper, nonmetals, taney, icd, angelique, wageningen,
# Nearest to question: inconsistent, blasphemy, valued, privileges, workgroups, jacobi, poli, gadolinite,
# Nearest to marriage: immoral, helmstedt, lahaye, manus, abduction, disgust, cw, slaying,
# Nearest to accepted: reconquering, bulgarians, bertold, null, qpl, pnh, essences, luk,
# Nearest to ocean: islands, mariana, soils, artefacts, ghana, faroe, cholesterol, trucial,
# Nearest to existence: albinism, rejected, nleutnant, impinging, proofs, inquire, outline, boarder,
# Nearest to cost: sally, investors, valuables, rated, uniform, bottomed, portable, proprietary,
# Nearest to applied: rejected, frankenheimer, sylvian, declare, zuse, fact, notions, ricardo,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2612 0.0277 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1286 0.0269 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1384 0.0264 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1369 0.0263 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0438 0.0264 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1466 0.0265 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1682 0.0264 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1137 0.0264 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1831 0.0046 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1265 0.0264 sec/batch
# Nearest to only: circulatory, seam, hornby, zone, thus, complex, booms, thoracic,
# Nearest to to: that, execute, in, precedent, before, shoot, simulators, not,
# Nearest to also: facilitate, features, mona, ridgway, bretagne, give, brands, nebulous,
# Nearest to s: christopher, goldwyn, sfsr, hewlett, unsystematic, lleida, objectification, ketcham,
# Nearest to time: hudd, donating, viz, kilometres, unmolested, mazes, rotherhithe, into,
# Nearest to of: the, important, forty, lawrence, ancien, petitioner, a, rector,
# Nearest to been: create, decades, usaid, absorbs, parris, lgbt, dampier, imbalance,
# Nearest to have: farce, spins, herrera, couples, lower, pyrolytic, macanese, confucians,
# Nearest to units: signor, appl, unit, steeper, nonmetals, predicts, icd, taney,
# Nearest to question: inconsistent, valued, blasphemy, gadolinite, poli, affine, workgroups, infliction,
# Nearest to marriage: immoral, helmstedt, lahaye, abduction, manus, substances, cw, disgust,
# Nearest to accepted: bulgarians, reconquering, null, bertold, essences, michio, qpl, pnh,
# Nearest to ocean: islands, mariana, soils, artefacts, intelsat, breezes, faroe, cholesterol,
# Nearest to existence: albinism, nleutnant, impinging, proofs, boarder, rejected, reichskammergericht, converge,
# Nearest to cost: sally, rated, bottomed, uniform, valuables, portable, investors, proprietary,
# Nearest to applied: zuse, frankenheimer, rejected, sylvian, susceptibility, fact, ricardo, linear,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0976 0.0273 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0991 0.0265 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0881 0.0264 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0548 0.0265 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0741 0.0264 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0284 0.0264 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0715 0.0263 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0892 0.0264 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1002 0.0263 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0285 0.0264 sec/batch
# Nearest to only: circulatory, thus, thoracic, of, seam, mantis, hornby, complex,
# Nearest to to: execute, in, that, not, refugee, shoot, ignores, before,
# Nearest to also: facilitate, give, of, features, substitution, mona, ridgway, nebulous,
# Nearest to s: christopher, goldwyn, sfsr, hewlett, disco, hain, objectification, coil,
# Nearest to time: hudd, donating, viz, kilometres, launched, incorrect, into, mazes,
# Nearest to of: the, a, forty, important, also, evanston, has, eight,
# Nearest to been: create, absorbs, moloch, usaid, decades, cortes, orthographic, lgbt,
# Nearest to have: spins, farce, couples, herrera, pyrolytic, immemorial, alone, luck,
# Nearest to units: signor, appl, unit, nonmetals, steeper, predicts, taney, aero,
# Nearest to question: inconsistent, valued, blasphemy, gadolinite, atheistic, workgroups, affine, poli,
# Nearest to marriage: immoral, helmstedt, lahaye, manus, substances, abduction, cw, hanssen,
# Nearest to accepted: reconquering, bulgarians, null, bertold, qpl, essences, michio, lingering,
# Nearest to ocean: islands, mariana, intelsat, cholesterol, artefacts, breezes, faroe, soils,
# Nearest to existence: impinging, reichskammergericht, albinism, nleutnant, rejected, inquire, aliasing, proofs,
# Nearest to cost: valuables, sally, rated, bottomed, portable, subseteq, uniform, investors,
# Nearest to applied: zuse, frankenheimer, rejected, ricardo, linear, sylvian, susceptibility, seawater,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0155 0.0272 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0133 0.0264 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0326 0.0263 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0598 0.0263 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0841 0.0263 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0395 0.0263 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0488 0.0263 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1107 0.0263 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0683 0.0264 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0457 0.0264 sec/batch
# Nearest to only: of, circulatory, thus, thoracic, complex, hornby, seam, be,
# Nearest to to: that, execute, not, in, ecb, investiture, of, they,
# Nearest to also: facilitate, substitution, of, give, features, discussing, nebulous, sequencers,
# Nearest to s: christopher, sfsr, hewlett, goldwyn, interlisp, ict, wrote, disco,
# Nearest to time: donating, hudd, viz, mechanics, mazes, incorrect, azimuth, kilometres,
# Nearest to of: the, a, important, forty, only, also, evanston, in,
# Nearest to been: create, absorbs, usaid, moloch, lgbt, orthographic, troubadors, decades,
# Nearest to have: couples, farce, spins, herrera, qualitative, immemorial, alone, pyrolytic,
# Nearest to units: appl, signor, unit, nonmetals, predicts, angelique, icd, aero,
# Nearest to question: inconsistent, blasphemy, valued, atheistic, gadolinite, affine, workgroups, philosophers,
# Nearest to marriage: immoral, helmstedt, lahaye, substances, manus, pyrrhus, abduction, children,
# Nearest to accepted: reconquering, null, bulgarians, essences, qpl, bertold, pnh, michio,
# Nearest to ocean: intelsat, islands, mariana, faroe, artefacts, falkland, cholesterol, breezes,
# Nearest to existence: impinging, albinism, proofs, rejected, theories, reichskammergericht, nleutnant, diddy,
# Nearest to cost: sally, rated, valuables, bottomed, subseteq, minix, investors, uniform,
# Nearest to applied: zuse, rejected, frankenheimer, ricardo, linear, seawater, susceptibility, sylvian,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0723 0.0273 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0796 0.0264 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0611 0.0264 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0700 0.0263 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0756 0.0265 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0244 0.0264 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0708 0.0264 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0780 0.0265 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0889 0.0264 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0889 0.0264 sec/batch
# Nearest to only: of, thus, circulatory, zone, hornby, complex, predispose, seam,
# Nearest to to: in, that, investiture, before, of, ecb, not, execute,
# Nearest to also: features, substitution, facilitate, ridgway, nebulous, discussing, mona, eunuchs,
# Nearest to s: christopher, goldwyn, sfsr, hewlett, ketcham, conner, wrote, objectification,
# Nearest to time: donating, hudd, kilometres, mechanics, viz, adret, mazes, azimuth,
# Nearest to of: the, in, forty, rhineland, to, and, a, evanston,
# Nearest to been: create, moloch, decades, lgbt, usaid, troubadors, orthographic, absorbs,
# Nearest to have: herrera, farce, spins, couples, luck, qualitative, immemorial, alone,
# Nearest to units: appl, signor, unit, nonmetals, pogrom, predicts, numbering, angelique,
# Nearest to question: inconsistent, blasphemy, valued, poli, atheistic, gadolinite, workgroups, infliction,
# Nearest to marriage: immoral, helmstedt, lahaye, manus, pyrrhus, abduction, cw, children,
# Nearest to accepted: reconquering, bulgarians, null, bertold, qpl, pnh, lingering, kbo,
# Nearest to ocean: intelsat, islands, mariana, artefacts, falkland, relay, cholesterol, faroe,
# Nearest to existence: impinging, albinism, proofs, nleutnant, reichskammergericht, inquire, rejected, jehu,
# Nearest to cost: valuables, rated, sally, bottomed, minix, subseteq, proprietary, burdens,
# Nearest to applied: zuse, rejected, frankenheimer, sylvian, ricardo, linear, seawater, inoffensive,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0627 0.0272 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0020 0.0264 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0540 0.0263 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0398 0.0264 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0586 0.0265 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1006 0.0265 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1059 0.0264 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0486 0.0265 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0418 0.0263 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0518 0.0263 sec/batch
# Nearest to only: thus, of, seam, zone, circulatory, hornby, complex, centrist,
# Nearest to to: that, in, not, execute, ecb, they, before, innermost,
# Nearest to also: features, facilitate, substitution, discussing, nebulous, ridgway, give, of,
# Nearest to s: christopher, goldwyn, sfsr, hewlett, wrote, ketcham, conner, skydiver,
# Nearest to time: donating, hudd, viz, kilometres, achievements, mechanics, adret, azimuth,
# Nearest to of: the, a, forty, in, evanston, important, eight, lower,
# Nearest to been: create, moloch, decades, lgbt, absorbs, seminal, usaid, orthographic,
# Nearest to have: spins, herrera, farce, couples, qualitative, luck, certain, pyrolytic,
# Nearest to units: appl, signor, unit, pogrom, nonmetals, taney, numbering, icd,
# Nearest to question: inconsistent, blasphemy, valued, atheistic, gadolinite, poli, workgroups, privileges,
# Nearest to marriage: immoral, helmstedt, lahaye, abduction, hanssen, pyrrhus, manus, rise,
# Nearest to accepted: bulgarians, reconquering, qpl, null, pnh, apparently, bertold, essences,
# Nearest to ocean: intelsat, islands, artefacts, mariana, falkland, breezes, faroe, cholesterol,
# Nearest to existence: impinging, albinism, proofs, reichskammergericht, nleutnant, bases, boarder, rejected,
# Nearest to cost: valuables, sally, bottomed, rated, minix, burdens, proprietary, investors,
# Nearest to applied: rejected, zuse, frankenheimer, ricardo, linear, sylvian, inoffensive, seawater,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0202 0.0273 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0412 0.0264 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0330 0.0264 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0441 0.0263 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0922 0.0264 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0456 0.0239 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0187 0.0265 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9890 0.0265 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9927 0.0264 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9936 0.0265 sec/batch
# Nearest to only: hornby, of, thus, circulatory, seam, zone, justly, mantis,
# Nearest to to: that, in, not, execute, before, they, for, of,
# Nearest to also: facilitate, features, give, ridgway, of, discussing, eunuchs, sequencers,
# Nearest to s: goldwyn, christopher, hewlett, sfsr, csc, forti, ict, unsystematic,
# Nearest to time: donating, hudd, kilometres, viz, achievements, mechanics, adret, azimuth,
# Nearest to of: the, a, forty, in, important, and, to, evanston,
# Nearest to been: moloch, lgbt, usaid, decades, create, absorbs, that, chalcedonian,
# Nearest to have: herrera, qualitative, couples, farce, spins, greenlanders, wording, immemorial,
# Nearest to units: appl, unit, signor, predicts, pogrom, icd, nonmetals, aero,
# Nearest to question: inconsistent, blasphemy, valued, atheistic, gadolinite, poli, privileges, workgroups,
# Nearest to marriage: immoral, abduction, guarantee, helmstedt, pyrrhus, children, lahaye, ironside,
# Nearest to accepted: reconquering, null, bulgarians, qpl, pnh, kbo, apparently, cosmos,
# Nearest to ocean: intelsat, islands, mariana, artefacts, breezes, faroe, earth, cholesterol,
# Nearest to existence: impinging, albinism, proofs, reichskammergericht, bases, nleutnant, jehu, boarder,
# Nearest to cost: sally, bottomed, valuables, market, minix, rated, burdens, subseteq,
# Nearest to applied: zuse, frankenheimer, rejected, ricardo, linear, sylvian, seawater, artist,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9831 0.0273 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9554 0.0264 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9841 0.0265 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0289 0.0263 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0231 0.0264 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9971 0.0270 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9316 0.0265 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9458 0.0264 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9206 0.0263 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9803 0.0264 sec/batch
# Nearest to only: of, thus, hornby, circulatory, seam, the, complex, mantis,
# Nearest to to: that, not, in, execute, for, before, of, they,
# Nearest to also: features, of, facilitate, give, sequencers, substitution, and, ridgway,
# Nearest to s: christopher, goldwyn, hewlett, csc, sfsr, conner, ict, upcoming,
# Nearest to time: donating, hudd, kilometres, mechanics, achievements, viz, adret, azimuth,
# Nearest to of: the, a, forty, in, eight, and, important, also,
# Nearest to been: usaid, decades, orthographic, lgbt, that, absorbs, create, egyptologists,
# Nearest to have: couples, herrera, alone, living, qualitative, farce, spins, are,
# Nearest to units: appl, unit, signor, predicts, pogrom, nonmetals, taney, aero,
# Nearest to question: inconsistent, blasphemy, valued, atheistic, gadolinite, poli, privileges, lumber,
# Nearest to marriage: immoral, ironside, lahaye, guarantee, hanssen, abduction, married, pyrrhus,
# Nearest to accepted: reconquering, pnh, bulgarians, null, qpl, kbo, lingering, apparently,
# Nearest to ocean: intelsat, islands, artefacts, mariana, earth, breezes, faroe, nicaragua,
# Nearest to existence: impinging, albinism, reichskammergericht, proofs, nleutnant, bases, inquire, golding,
# Nearest to cost: sally, valuables, bottomed, subseteq, burdens, patronage, rated, archaeal,
# Nearest to applied: zuse, frankenheimer, linear, ricardo, rejected, seawater, sylvian, artist,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0083 0.0276 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0204 0.0266 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9475 0.0264 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0334 0.0263 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0412 0.0264 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9568 0.0264 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0019 0.0264 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0035 0.0263 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9702 0.0264 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9941 0.0263 sec/batch
# Nearest to only: of, thus, hornby, complex, circulatory, the, abhidharma, predispose,
# Nearest to to: that, in, not, for, investiture, of, before, they,
# Nearest to also: features, of, facilitate, substitution, discussing, sequencers, and, give,
# Nearest to s: goldwyn, hewlett, christopher, ketcham, sfsr, conner, csc, upcoming,
# Nearest to time: donating, hudd, achievements, mechanics, azimuth, much, kilometres, hyped,
# Nearest to of: the, a, in, forty, also, only, eight, evanston,
# Nearest to been: lgbt, usaid, decades, create, moloch, that, absorbs, orthographic,
# Nearest to have: herrera, couples, are, alone, farce, living, wording, greenlanders,
# Nearest to units: appl, unit, signor, nonmetals, predicts, pogrom, medium, taney,
# Nearest to question: inconsistent, blasphemy, valued, atheistic, gadolinite, privileges, poli, workgroups,
# Nearest to marriage: immoral, married, lahaye, hanssen, children, abduction, helmstedt, substances,
# Nearest to accepted: qpl, reconquering, null, apparently, kbo, pnh, bulgarians, cosmos,
# Nearest to ocean: intelsat, islands, mariana, faroe, artefacts, earth, breezes, relay,
# Nearest to existence: impinging, albinism, proofs, reichskammergericht, theories, bases, nleutnant, jehu,
# Nearest to cost: sally, valuables, bottomed, investors, subseteq, burdens, rated, market,
# Nearest to applied: zuse, rejected, frankenheimer, linear, ricardo, seawater, aino, sylvian,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9878 0.0273 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9662 0.0265 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9803 0.0264 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9980 0.0264 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0159 0.0265 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0174 0.0265 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9513 0.0263 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9635 0.0265 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9683 0.0264 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0149 0.0266 sec/batch
# Nearest to only: of, thus, ceased, the, busses, ludo, meetings, complex,
# Nearest to to: that, in, not, of, the, for, before, by,
# Nearest to also: features, of, facilitate, and, discussing, substitution, sequencers, such,
# Nearest to s: goldwyn, christopher, hewlett, sfsr, ict, faa, sonia, hain,
# Nearest to time: donating, hudd, achievements, mechanics, adret, azimuth, kilometres, viz,
# Nearest to of: the, in, a, and, to, forty, only, important,
# Nearest to been: usaid, lgbt, decades, that, create, orthographic, absorbs, in,
# Nearest to have: are, herrera, wording, couples, pyrolytic, spins, alone, living,
# Nearest to units: appl, unit, signor, pogrom, taney, numbering, nonmetals, predicts,
# Nearest to question: inconsistent, blasphemy, atheistic, gadolinite, valued, privileges, workgroups, poli,
# Nearest to marriage: immoral, married, children, abduction, hanssen, lahaye, helmstedt, substances,
# Nearest to accepted: qpl, pnh, reconquering, null, apparently, kbo, bulgarians, cubs,
# Nearest to ocean: intelsat, islands, mariana, relay, faroe, earth, artefacts, breezes,
# Nearest to existence: impinging, albinism, reichskammergericht, bases, theories, proofs, jehu, nleutnant,
# Nearest to cost: sally, valuables, burdens, investors, bottomed, subseteq, rated, patronage,
# ...
# Nearest to cost: costs, superceded, rated, zagreb, subseteq, aluminium, utility, ua,
# Nearest to applied: linear, frankenheimer, deprogrammer, seawater, zuse, movable, sylvian, typographic,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8796 0.0273 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7547 0.0264 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8382 0.0264 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7820 0.0264 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8010 0.0264 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8482 0.0264 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8564 0.0264 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8313 0.0265 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8503 0.0263 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9357 0.0265 sec/batch
# Nearest to only: of, the, a, most, thus, it, and, as,
# Nearest to to: that, in, the, for, of, a, and, with,
# Nearest to also: and, of, in, as, s, features, to, an,
# Nearest to s: and, the, a, of, in, nine, also, to,
# Nearest to time: donating, to, did, be, arrived, eventually, as, in,
# Nearest to of: the, a, and, in, is, as, to, for,
# Nearest to been: that, since, decades, evidence, were, dozen, have, found,
# Nearest to have: are, least, been, of, and, any, living, or,
# Nearest to units: unit, appl, bipm, signor, centimetre, nonmetals, predicts, si,
# Nearest to question: inconsistent, questions, answer, assume, indium, answers, lumber, disguise,
# Nearest to marriage: married, immoral, divorce, cultures, children, mistresses, daughter, abduction,
# Nearest to accepted: pnh, panini, qpl, kbo, believed, reconquering, cubs, apparently,
# Nearest to ocean: intelsat, relay, mariana, cholesterol, earth, islands, nagano, submarine,
# Nearest to existence: albinism, jehu, reductive, ontological, bases, formaldehyde, golding, quantifier,
# Nearest to cost: costs, rated, superceded, aluminium, subseteq, zagreb, utility, sally,
# Nearest to applied: linear, frankenheimer, deprogrammer, zuse, bundles, seawater, movers, typographic,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8383 0.0273 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8333 0.0264 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8609 0.0264 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8313 0.0264 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8524 0.0264 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8575 0.0264 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8640 0.0264 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8512 0.0264 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8843 0.0265 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8444 0.0266 sec/batch
# Nearest to only: of, most, the, thus, a, it, and, ludo,
# Nearest to to: that, of, in, the, and, with, a, for,
# Nearest to also: and, of, s, features, in, as, such, or,
# Nearest to s: and, in, of, the, a, nine, also, by,
# Nearest to time: donating, did, arrived, eventually, soon, began, adret, know,
# Nearest to of: the, and, in, a, to, as, is, for,
# Nearest to been: were, that, decades, since, evidence, dozen, have, has,
# Nearest to have: are, least, of, more, many, been, and, that,
# Nearest to units: unit, appl, bipm, signor, centimetre, nonmetals, si, numbering,
# Nearest to question: inconsistent, answer, questions, assume, indium, disguise, sorensen, answers,
# Nearest to marriage: married, immoral, divorce, cultures, children, abduction, daughter, mistresses,
# Nearest to accepted: pnh, believed, reconquering, kbo, essences, panini, apparently, qpl,
# Nearest to ocean: intelsat, relay, cholesterol, islands, mariana, earth, pacific, submarine,
# Nearest to existence: albinism, reductive, ontological, jehu, bases, quantifier, surrounded, golding,
# Nearest to cost: costs, rated, superceded, zagreb, aluminium, subseteq, ua, bri,
# Nearest to applied: linear, frankenheimer, deprogrammer, seawater, bundles, zuse, graveyards, typographic,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8641 0.0277 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8735 0.0266 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8304 0.0266 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8341 0.0269 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8828 0.0267 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8213 0.0266 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9524 0.0265 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8865 0.0265 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9201 0.0265 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8127 0.0264 sec/batch
# Nearest to only: of, most, a, the, thus, it, ludo, and,
# Nearest to to: in, of, that, the, and, with, not, for,
# Nearest to also: and, of, such, other, in, s, features, as,
# Nearest to s: and, in, of, the, nine, a, also, to,
# Nearest to time: donating, arrived, adret, submitted, soon, eventually, hudd, pickers,
# Nearest to of: the, in, and, a, to, as, for, is,
# Nearest to been: were, decades, since, has, that, dozen, have, evidence,
# Nearest to have: are, least, been, more, of, many, or, and,
# Nearest to units: unit, appl, bipm, signor, centimetre, si, nonmetals, numbering,
# Nearest to question: questions, answer, inconsistent, assume, indium, answers, disguise, sorensen,
# Nearest to marriage: married, immoral, divorce, cultures, children, abduction, daughter, mistresses,
# Nearest to accepted: pnh, reconquering, panini, believed, qpl, essences, kbo, glimpse,
# Nearest to ocean: intelsat, relay, cholesterol, earth, mariana, islands, submarine, coaxial,
# Nearest to existence: albinism, reductive, bases, ontological, jehu, golding, surrounded, quantifier,
# Nearest to cost: costs, superceded, rated, zagreb, aluminium, subseteq, ua, utility,
# Nearest to applied: frankenheimer, linear, deprogrammer, graveyards, bundles, typographic, sylvian, movers,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7722 0.0273 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8781 0.0265 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7939 0.0265 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8673 0.0265 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8811 0.0263 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8549 0.0263 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9011 0.0131 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8254 0.0265 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8618 0.0264 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8494 0.0266 sec/batch
# Nearest to only: of, the, most, a, thus, it, and, ludo,
# Nearest to to: in, of, that, with, the, and, a, not,
# Nearest to also: and, of, s, in, as, other, features, an,
# Nearest to s: and, of, in, a, the, to, also, nine,
# Nearest to time: donating, began, soon, to, adret, arrived, was, aristarchus,
# Nearest to of: the, in, and, a, to, as, eight, for,
# Nearest to been: were, have, decades, that, since, dozen, has, in,
# Nearest to have: are, least, been, of, or, to, and, that,
# Nearest to units: unit, appl, bipm, si, centimetre, signor, cgpm, nonmetals,
# Nearest to question: questions, answer, inconsistent, indium, answers, assume, disguise, sorensen,
# Nearest to marriage: married, immoral, cultures, divorce, abduction, children, mistress, mistresses,
# Nearest to accepted: pnh, panini, kbo, believed, reconquering, essences, qpl, validity,
# Nearest to ocean: intelsat, relay, cholesterol, earth, submarine, oceanic, mariana, islands,
# Nearest to existence: albinism, reductive, ontological, quantifier, golding, bases, jehu, surrounded,
# Nearest to cost: costs, rated, superceded, zagreb, subseteq, aluminium, utility, ua,
# Nearest to applied: frankenheimer, graveyards, linear, deprogrammer, typographic, movable, bundles, seawater,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8315 0.0273 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8132 0.0264 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8364 0.0264 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7777 0.0264 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8598 0.0264 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8633 0.0264 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8508 0.0264 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7596 0.0265 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8222 0.0265 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7882 0.0264 sec/batch
# Nearest to only: of, the, a, most, and, thus, it, as,
# Nearest to to: in, that, of, the, a, for, not, and,
# Nearest to also: and, of, as, in, s, to, with, such,
# Nearest to s: and, of, the, in, also, a, nine, to,
# Nearest to time: to, donating, computed, in, eventually, pickers, same, began,
# Nearest to of: the, in, and, to, a, is, as, for,
# Nearest to been: have, has, decades, since, that, in, were, it,
# Nearest to have: are, least, been, of, to, that, and, any,
# Nearest to units: unit, appl, bipm, centimetre, signor, nonmetals, forces, si,
# Nearest to question: answer, questions, inconsistent, answers, assume, indium, disguise, sorensen,
# Nearest to marriage: married, immoral, cultures, divorce, abduction, children, mistress, daughter,
# Nearest to accepted: pnh, believed, reconquering, kbo, panini, cubs, glimpse, overtaking,
# Nearest to ocean: intelsat, relay, cholesterol, earth, oceanic, pacific, mariana, submarine,
# Nearest to existence: albinism, reductive, quantifier, surrounded, its, ontological, formaldehyde, golding,
# Nearest to cost: costs, rated, superceded, zagreb, subseteq, aluminium, valuables, unrealistic,
# Nearest to applied: linear, frankenheimer, graveyards, typographic, bundles, deprogrammer, movable, weapons,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7543 0.0274 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7880 0.0268 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8641 0.0265 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8172 0.0264 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8160 0.0264 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8928 0.0264 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8470 0.0266 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8265 0.0264 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8005 0.0264 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8593 0.0265 sec/batch
# Nearest to only: of, the, most, a, and, it, thus, as,
# Nearest to to: of, that, in, the, and, with, a, for,
# Nearest to also: and, of, in, as, to, s, such, the,
# Nearest to s: and, the, a, of, in, nine, also, to,
# Nearest to time: to, in, donating, same, the, eventually, began, arrived,
# Nearest to of: the, in, and, a, to, is, as, for,
# Nearest to been: were, that, have, has, decades, since, in, however,
# Nearest to have: are, least, been, of, and, more, or, the,
# Nearest to units: unit, appl, bipm, centimetre, signor, nonmetals, inferred, si,
# Nearest to question: questions, answer, inconsistent, answers, indium, assume, disguise, sorensen,
# Nearest to marriage: married, immoral, divorce, cultures, children, abduction, mistresses, mistress,
# Nearest to accepted: pnh, kbo, panini, believed, essences, reconquering, overtaking, qpl,
# Nearest to ocean: intelsat, relay, cholesterol, oceanic, submarine, earth, mariana, arabsat,
# Nearest to existence: reductive, ontological, albinism, quantifier, materialistic, surrounded, bases, theories,
# Nearest to cost: costs, rated, zagreb, perish, superceded, subseteq, aluminium, aix,
# Nearest to applied: deprogrammer, linear, frankenheimer, lends, graveyards, bundles, typographic, weapons,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8553 0.0275 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8145 0.0264 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8134 0.0265 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8552 0.0266 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8873 0.0266 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8451 0.0267 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8298 0.0266 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8652 0.0267 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8247 0.0266 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8085 0.0267 sec/batch
# Nearest to only: of, the, a, most, and, it, which, thus,
# Nearest to to: of, in, the, that, and, with, a, other,
# Nearest to also: and, of, in, as, to, s, or, an,
# Nearest to s: and, the, of, in, a, also, to, by,
# Nearest to time: donating, in, began, to, arrived, submitted, soon, the,
# Nearest to of: the, in, and, to, a, as, which, is,
# Nearest to been: were, has, have, that, since, decades, in, it,
# Nearest to have: are, of, been, least, more, that, and, the,
# Nearest to units: unit, appl, bipm, centimetre, inferred, signor, numbering, nonmetals,
# Nearest to question: answer, questions, inconsistent, indium, assume, disguise, answers, sorensen,
# Nearest to marriage: married, immoral, cultures, divorce, abduction, children, mistress, mistresses,
# Nearest to accepted: pnh, kbo, validity, believed, panini, essences, qpl, overtaking,
# Nearest to ocean: intelsat, relay, cholesterol, mariana, oceanic, pacific, submarine, coaxial,
# Nearest to existence: reductive, albinism, bases, ontological, quantifier, diddy, surrounded, its,
# Nearest to cost: costs, zagreb, rated, superceded, perish, aix, unrealistic, valuables,
# Nearest to applied: linear, deprogrammer, frankenheimer, graveyards, bundles, movable, sylvian, lends,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8670 0.0273 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8369 0.0268 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8933 0.0270 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9168 0.0269 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9098 0.0266 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8485 0.0267 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7945 0.0266 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8021 0.0264 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7368 0.0265 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8684 0.0266 sec/batch
# Nearest to only: of, a, most, the, thus, and, it, ludo,
# Nearest to to: of, in, the, and, that, with, a, for,
# Nearest to also: and, of, in, as, other, s, to, many,
# Nearest to s: and, of, in, a, the, by, also, nine,
# Nearest to time: soon, donating, to, was, predated, began, hudd, submitted,
# Nearest to of: the, in, and, a, to, is, for, as,
# Nearest to been: were, has, since, decades, have, in, dozen, however,
# Nearest to have: are, been, least, of, common, more, or, these,
# Nearest to units: unit, appl, bipm, inferred, centimetre, si, nonmetals, numbering,
# Nearest to question: answer, questions, inconsistent, indium, assume, disguise, answers, sorensen,
# Nearest to marriage: married, immoral, divorce, cultures, abduction, mistresses, children, mistress,
# Nearest to accepted: pnh, panini, believed, kbo, reconquering, essences, glimpse, validity,
# Nearest to ocean: intelsat, relay, earth, cholesterol, mariana, arabsat, coaxial, submarine,
# Nearest to existence: reductive, ontological, albinism, bases, quantifier, diddy, formaldehyde, materialistic,
# Nearest to cost: costs, zagreb, rated, perish, subseteq, bri, aluminium, superceded,
# Nearest to applied: linear, frankenheimer, deprogrammer, graveyards, lends, movable, typographic, bundles,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8530 0.0275 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8365 0.0266 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
