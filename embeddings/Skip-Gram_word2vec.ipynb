# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    range_size = np.random.randint(1, window_size+1)
    start = idx-range_size if (idx-range_size) > 0 else 0
    stop = idx+range_size
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6958 0.0274 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6287 0.0262 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5009 0.0263 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5944 0.0263 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5086 0.0262 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5364 0.0261 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5571 0.0262 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5781 0.0262 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4538 0.0264 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4013 0.0263 sec/batch
# Nearest to all: niche, remain, unites, generis, disciplinarian, ethic, kilns, crush,
# Nearest to called: protists, cjd, amigabasic, attack, gobierno, biodegradable, privateers, gpu,
# Nearest to so: vale, deleterious, donkey, casa, simultaneously, fecture, satellite, retardant,
# Nearest to th: spacetimes, side, peerage, hadj, eight, courageous, parrot, obesity,
# Nearest to an: jur, tradition, lite, done, maois, wheelers, onside, keen,
# Nearest to time: szl, dance, notorious, novoselic, fux, probing, scholarly, bnf,
# Nearest to may: mount, wonka, minimizes, balaton, aa, inelastic, slbms, pushed,
# Nearest to that: quebec, stand, enzyme, zemlya, cache, sliced, rhenish, harmed,
# Nearest to paris: predynastic, difference, psychology, sylvia, sides, yn, tilsit, isaf,
# Nearest to mean: organisms, hanko, braille, exactly, decca, odham, hamelin, risk,
# Nearest to active: ambients, sideshow, workbench, whole, reinforces, legalistic, cryptanalytic, rst,
# Nearest to governor: shivaji, cristae, ausgleich, worked, knuckle, architectures, nickname, changing,
# Nearest to pressure: saxophonist, designing, honestly, sported, gpl, agents, archangel, depths,
# Nearest to engine: entendres, merina, plano, together, chs, solicitor, vesicles, weekend,
# Nearest to san: repress, tyrolean, nomos, sextans, levy, surfacing, alliances, charles,
# Nearest to test: curl, slide, seventh, fought, haines, cody, universala, totowa,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4490 0.0273 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3453 0.0262 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3144 0.0263 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2004 0.0263 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1807 0.0263 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1421 0.0263 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1174 0.0262 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0391 0.0263 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0095 0.0262 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9941 0.0263 sec/batch
# Nearest to all: niche, remain, into, separation, ethic, unites, style, crush,
# Nearest to called: attack, cjd, expressed, noted, protists, outfits, biodegradable, patented,
# Nearest to so: simultaneously, satellite, mickey, deleterious, vale, adopt, recommend, wichita,
# Nearest to th: side, eight, peerage, kong, aborted, spacetimes, obesity, speaking,
# Nearest to an: done, tradition, jur, lite, formulated, working, maois, wheelers,
# Nearest to time: dance, notorious, scholarly, andhra, novoselic, kills, comprised, tone,
# Nearest to may: mount, minimizes, differences, judaism, aa, pushed, distant, ayling,
# Nearest to that: stand, quebec, enzyme, contemporary, cache, proceedings, zemlya, staff,
# Nearest to paris: difference, sides, psychology, set, predynastic, yn, tilsit, sylvia,
# Nearest to mean: exactly, organisms, risk, lambda, requested, braille, decca, michael,
# Nearest to active: sideshow, whole, ambients, workbench, event, sed, legalistic, post,
# Nearest to governor: worked, architectures, masonic, nickname, knuckle, changing, shivaji, stiff,
# Nearest to pressure: saxophonist, designing, agents, sported, needs, gpl, depths, cry,
# Nearest to engine: together, entendres, merina, weekend, eastern, shame, plano, since,
# Nearest to san: charles, repress, nomos, teenager, buck, buford, restored, levy,
# Nearest to test: seventh, fought, slide, curl, body, recorders, cody, haines,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9239 0.0272 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9017 0.0262 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8667 0.0263 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8631 0.0263 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7974 0.0263 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8242 0.0262 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7836 0.0263 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7906 0.0262 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7954 0.0263 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7899 0.0263 sec/batch
# Nearest to all: niche, remain, unites, ethic, into, reliably, separation, crush,
# Nearest to called: protists, cjd, expressed, attack, patented, noted, repatriation, microwaves,
# Nearest to so: simultaneously, dollars, deleterious, vale, adopt, donkey, recommend, satellite,
# Nearest to th: side, peerage, eight, kong, courageous, obesity, spacetimes, upheavals,
# Nearest to an: lite, formulated, jur, accorded, maois, phys, faith, fellowships,
# Nearest to time: notorious, dance, tone, andhra, scholarly, szl, comprised, kills,
# Nearest to may: mount, aa, inelastic, minimizes, pushed, steve, dlp, ayling,
# Nearest to that: stand, quebec, cache, mutually, secondly, harmed, forensics, enzyme,
# Nearest to paris: difference, psychology, sides, sylvia, tilsit, isaf, set, yn,
# Nearest to mean: organisms, exactly, lambda, risk, braille, bipartite, requested, hanko,
# Nearest to active: sideshow, ambients, whole, legalistic, workbench, reinforces, sed, boleslaus,
# Nearest to governor: architectures, worked, masonic, stalled, cristae, knuckle, nickname, changing,
# Nearest to pressure: gpl, depths, saxophonist, designing, agents, sported, needs, timely,
# Nearest to engine: entendres, together, merina, solicitor, plano, weekend, shame, exchanging,
# Nearest to san: charles, buck, repress, restored, levy, nomos, arthurian, teenager,
# Nearest to test: seventh, slide, fought, curl, recorders, cody, haines, body,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7771 0.0272 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7437 0.0263 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7133 0.0263 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7018 0.0262 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7615 0.0264 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6989 0.0263 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7084 0.0264 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7335 0.0263 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6974 0.0263 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6391 0.0262 sec/batch
# Nearest to all: niche, remain, unites, ethic, thrace, crush, separation, reliably,
# Nearest to called: protists, expressed, cjd, repatriation, patented, microwaves, privateers, attack,
# Nearest to so: vale, simultaneously, dollars, secreted, donkey, adopt, recommend, deleterious,
# Nearest to th: eight, side, peerage, flourished, kong, courageous, parrot, upheavals,
# Nearest to an: lite, maois, formulated, jur, fellowships, processors, phys, accorded,
# Nearest to time: notorious, dance, szl, novoselic, tone, kills, breached, andhra,
# Nearest to may: inelastic, mount, wonka, minimizes, aa, elizabethan, dlp, provoking,
# Nearest to that: stand, quebec, cache, forensics, mutually, khz, remonstrance, emblem,
# Nearest to paris: difference, sylvia, sides, psychology, isaf, predynastic, heel, brimstone,
# Nearest to mean: organisms, exactly, lambda, risk, implies, hamelin, is, braille,
# Nearest to active: sideshow, ambients, reinforces, legalistic, whole, workbench, phyla, boleslaus,
# Nearest to governor: masonic, worked, shivaji, architectures, stalled, joni, knuckle, cristae,
# Nearest to pressure: depths, sported, gpl, designing, agents, honestly, timely, saxophonist,
# Nearest to engine: entendres, merina, plano, solicitor, together, weekend, vesicles, exchanging,
# Nearest to san: charles, buck, teenager, courland, surfacing, repress, levy, restored,
# Nearest to test: slide, seventh, haines, curl, recorders, cody, body, alternating,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6952 0.0271 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6746 0.0264 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6269 0.0264 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6469 0.0263 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6273 0.0264 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6357 0.0263 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5919 0.0193 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5378 0.0262 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5208 0.0262 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5030 0.0264 sec/batch
# Nearest to all: niche, unites, remain, thrace, into, separation, ethic, crush,
# Nearest to called: protists, expressed, microwaves, transformations, cations, repatriation, cjd, cupid,
# Nearest to so: simultaneously, vale, secreted, adopt, donkey, deleterious, actual, imbalance,
# Nearest to th: flourished, eight, peerage, parrot, speaking, empire, side, upheavals,
# Nearest to an: formulated, lite, maois, thumbnails, jur, funimation, processors, phys,
# Nearest to time: notorious, szl, this, dance, novoselic, comprised, tone, breached,
# Nearest to may: inelastic, aa, elizabethan, dlp, provoking, minimizes, dealerships, captaincy,
# Nearest to that: stand, quebec, mutually, irritation, forensics, gtk, cache, remonstrance,
# Nearest to paris: sylvia, predynastic, sides, isaf, psychology, difference, brimstone, heel,
# Nearest to mean: organisms, lambda, exactly, is, risk, implies, hostetler, hamelin,
# Nearest to active: sideshow, ambients, reinforces, legalistic, phyla, whole, workbench, mri,
# Nearest to governor: shivaji, masonic, stalled, joni, worked, cristae, ukrainian, knuckle,
# Nearest to pressure: sported, gpl, depths, designing, agents, honestly, needs, timely,
# Nearest to engine: merina, plano, entendres, weekend, solicitor, together, vesicles, grease,
# Nearest to san: charles, buck, courland, surfacing, restored, levy, teenager, diefenbaker,
# Nearest to test: slide, seventh, haines, curl, recorders, body, alternating, cody,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5084 0.0273 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5014 0.0263 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4628 0.0263 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5091 0.0262 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4963 0.0263 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4835 0.0263 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4793 0.0263 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4122 0.0263 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4376 0.0263 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4314 0.0268 sec/batch
# Nearest to all: niche, unites, remain, separation, thrace, style, draw, into,
# Nearest to called: protists, transformations, expressed, cations, microwaves, compute, beelzebub, vortex,
# Nearest to so: adopt, simultaneously, secreted, imbalance, vale, donkey, disproving, casein,
# Nearest to th: flourished, side, parrot, barratry, kong, speaking, cooking, muslims,
# Nearest to an: lite, formulated, thumbnails, maois, processors, funimation, entre, phys,
# Nearest to time: notorious, this, tone, scratched, novoselic, breached, crowther, bnf,
# Nearest to may: inelastic, dealerships, aa, starches, elizabethan, dlp, provoking, distant,
# Nearest to that: mutually, stand, gtk, they, forensics, hardline, irritation, counselling,
# Nearest to paris: predynastic, sylvia, isaf, reorganised, brimstone, sides, slaveholders, heel,
# Nearest to mean: organisms, lambda, exactly, is, hostetler, implies, density, risk,
# Nearest to active: sideshow, ambients, reinforces, cryptanalytic, phyla, legalistic, mri, workbench,
# Nearest to governor: shivaji, masonic, joni, stalled, ukrainian, wiles, knuckle, cristae,
# Nearest to pressure: sported, gpl, depths, needs, agents, designing, honestly, microprocessors,
# Nearest to engine: merina, plano, entendres, latent, buffer, vesicles, propelled, sinuous,
# Nearest to san: charles, courland, buck, surfacing, teenager, manila, diefenbaker, restored,
# Nearest to test: slide, recorders, curl, body, cody, seventh, totowa, alternating,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4851 0.0272 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4054 0.0263 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4342 0.0263 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3913 0.0263 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4162 0.0262 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4107 0.0263 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3686 0.0263 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3846 0.0264 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4056 0.0263 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3627 0.0264 sec/batch
# Nearest to all: niche, unites, remain, thrace, style, draw, separation, generis,
# Nearest to called: protists, expressed, transformations, cations, beelzebub, microwaves, vortex, cjd,
# Nearest to so: secreted, imbalance, simultaneously, adopt, vale, disproving, donkey, deleterious,
# Nearest to th: flourished, barratry, peerage, chrysostom, side, kong, raping, speaking,
# Nearest to an: formulated, thumbnails, lite, phys, maois, processors, entre, wrapping,
# Nearest to time: notorious, this, turbines, fux, tone, crowther, breached, novoselic,
# Nearest to may: inelastic, dealerships, starches, aa, provoking, ramifications, distant, elizabethan,
# Nearest to that: stand, they, segmenting, mutually, belief, counselling, irritation, gtk,
# Nearest to paris: sylvia, predynastic, isaf, reorganised, consorts, heel, slaveholders, brimstone,
# Nearest to mean: lambda, organisms, exactly, hostetler, is, implies, joked, risk,
# Nearest to active: sideshow, ambients, reinforces, phyla, mri, cryptanalytic, legalistic, event,
# Nearest to governor: shivaji, masonic, joni, stalled, wiles, ukrainian, worked, cristae,
# Nearest to pressure: sported, agents, gpl, depths, designing, microprocessors, needs, inertial,
# Nearest to engine: plano, merina, diesel, propelled, sinuous, latent, buffer, together,
# Nearest to san: courland, charles, buck, surfacing, bernardi, manila, teenager, diefenbaker,
# Nearest to test: slide, recorders, alternating, totowa, haines, nanoscale, body, curl,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3884 0.0272 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4095 0.0264 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3599 0.0264 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3708 0.0263 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4343 0.0263 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3511 0.0263 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3990 0.0264 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3808 0.0263 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3238 0.0263 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3318 0.0262 sec/batch
# Nearest to all: niche, unites, remain, thrace, style, disable, ethic, disciplinarian,
# Nearest to called: protists, cations, transformations, expressed, beelzebub, gobierno, vortex, biodegradable,
# Nearest to so: secreted, adopt, imbalance, disproving, vale, meals, simultaneously, deleterious,
# Nearest to th: flourished, raping, barratry, side, chrysostom, speaking, jutland, unspectacular,
# Nearest to an: thumbnails, formulated, lite, maois, phys, valuations, processors, funimation,
# Nearest to time: notorious, crowther, fux, this, turbines, probing, scratched, tone,
# Nearest to may: inelastic, starches, dealerships, questioner, provoking, aa, ramifications, mount,
# Nearest to that: stand, segmenting, they, hardline, mesolithic, forensics, mutually, even,
# Nearest to paris: sylvia, predynastic, isaf, reorganised, consorts, heel, brimstone, slaveholders,
# Nearest to mean: lambda, organisms, exactly, hostetler, is, implies, joked, xiamen,
# Nearest to active: sideshow, ambients, reinforces, mri, phyla, cryptanalytic, legalistic, event,
# Nearest to governor: shivaji, masonic, joni, wiles, chairman, stalled, worked, ukrainian,
# Nearest to pressure: sported, depths, agents, inertial, timely, gpl, designing, constant,
# Nearest to engine: plano, merina, diesel, propelled, latent, weigh, sinuous, buffer,
# Nearest to san: courland, buck, charles, surfacing, manila, bernardi, diefenbaker, teenager,
# Nearest to test: slide, recorders, alternating, nanoscale, totowa, haines, weasels, curl,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3402 0.0272 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2729 0.0264 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.4109 0.0264 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3665 0.0264 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4154 0.0263 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3004 0.0264 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2802 0.0265 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3324 0.0266 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2314 0.0264 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3234 0.0264 sec/batch
# Nearest to all: niche, unites, disable, remain, thrace, style, draw, monegasque,
# Nearest to called: protists, transformations, cations, beelzebub, expressed, privateers, gobierno, jahangir,
# Nearest to so: adopt, secreted, imbalance, disproving, multinomial, vale, meals, casein,
# Nearest to th: flourished, raping, barratry, chrysostom, speaking, unrepresented, side, muslims,
# Nearest to an: thumbnails, formulated, maois, lite, farthest, funimation, valuations, cloudbusting,
# Nearest to time: notorious, fux, crowther, turbines, this, tone, probing, kills,
# Nearest to may: inelastic, dealerships, aa, ramifications, questioner, provoking, cubed, starches,
# Nearest to that: laparoscopic, segmenting, stand, shuffles, discretion, hardline, even, secondly,
# Nearest to paris: sylvia, predynastic, reorganised, isaf, heel, consorts, sides, colonized,
# Nearest to mean: lambda, exactly, organisms, is, hostetler, implies, xiamen, i,
# Nearest to active: ambients, reinforces, sideshow, phyla, cryptanalytic, mri, legalistic, geology,
# Nearest to governor: shivaji, masonic, chairman, joni, wiles, devasting, worked, bill,
# Nearest to pressure: sported, agents, depths, timely, subiaco, inertial, rockets, promotions,
# Nearest to engine: merina, plano, diesel, propelled, sinuous, latent, oily, buffer,
# Nearest to san: courland, buck, surfacing, manila, bernardi, diefenbaker, restored, flight,
# Nearest to test: slide, recorders, totowa, alternating, weasels, nanoscale, haines, wanderer,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2820 0.0273 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2865 0.0264 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3513 0.0120 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2491 0.0265 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2408 0.0263 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2121 0.0264 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2180 0.0263 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1965 0.0263 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2216 0.0263 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1647 0.0263 sec/batch
# Nearest to all: niche, unites, thrace, disable, style, remain, draw, monegasque,
# Nearest to called: protists, cations, name, transformations, beelzebub, privateers, expressed, jahangir,
# Nearest to so: adopt, secreted, imbalance, disproving, dispelled, simultaneously, meals, predated,
# Nearest to th: flourished, century, raping, chrysostom, side, barratry, speaking, chimpanzees,
# Nearest to an: thumbnails, lite, formulated, phys, funimation, farthest, valuations, cloudbusting,
# Nearest to time: notorious, fux, this, crowther, turbines, kills, probing, scratched,
# Nearest to may: inelastic, dealerships, aa, mount, provoking, cubed, starches, ramifications,
# Nearest to that: laparoscopic, even, segmenting, stand, irritation, shuffles, mutually, harmed,
# Nearest to paris: reorganised, sylvia, predynastic, heel, isaf, consorts, brimstone, monarchic,
# Nearest to mean: lambda, organisms, exactly, hostetler, is, xiamen, density, implies,
# Nearest to active: ambients, reinforces, sideshow, phyla, mri, cryptanalytic, legalistic, geology,
# Nearest to governor: shivaji, masonic, wiles, chairman, joni, saipan, devasting, bill,
# Nearest to pressure: sported, subiaco, agents, depths, timely, inertial, rockets, promotions,
# Nearest to engine: merina, propelled, diesel, plano, sinuous, repairing, automobile, engines,
# Nearest to san: courland, manila, bernardi, buck, surfacing, diefenbaker, butte, landry,
# Nearest to test: slide, recorders, totowa, alternating, chadwick, weasels, wanderer, nanoscale,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2263 0.0272 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2329 0.0263 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2111 0.0263 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1676 0.0263 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1809 0.0264 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1598 0.0264 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1567 0.0262 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1654 0.0263 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2078 0.0263 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1777 0.0263 sec/batch
# Nearest to all: niche, unites, disable, draw, style, thrace, monegasque, remain,
# Nearest to called: protists, cations, transformations, a, beelzebub, name, biodegradable, expressed,
# Nearest to so: adopt, secreted, disproving, imbalance, dispelled, simultaneously, casein, multinomial,
# Nearest to th: flourished, raping, century, side, fenwick, chrysostom, cooking, barratry,
# Nearest to an: thumbnails, formulated, funimation, valuations, maois, farthest, accorded, lite,
# Nearest to time: fux, this, crowther, turbines, tone, notorious, scratched, probing,
# Nearest to may: inelastic, dealerships, cubed, aa, starches, provoking, questioner, mount,
# Nearest to that: laparoscopic, segmenting, even, secondly, they, harmed, stand, shuffles,
# Nearest to paris: reorganised, sylvia, predynastic, heel, isaf, watts, consorts, yn,
# Nearest to mean: lambda, organisms, xiamen, exactly, hostetler, i, is, density,
# Nearest to active: ambients, mri, phyla, reinforces, cryptanalytic, legalistic, sideshow, catheter,
# Nearest to governor: shivaji, wiles, masonic, joni, devasting, chairman, saipan, neutralist,
# Nearest to pressure: sported, subiaco, constant, depths, agents, rockets, inertial, observes,
# Nearest to engine: propelled, diesel, merina, plano, engines, automobile, repairing, piston,
# Nearest to san: courland, manila, bernardi, landry, buck, butte, diefenbaker, balanchine,
# Nearest to test: slide, recorders, totowa, alternating, nanoscale, wanderer, chadwick, seventh,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1800 0.0271 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2119 0.0263 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1532 0.0264 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1414 0.0263 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2041 0.0263 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1815 0.0264 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1937 0.0263 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1626 0.0263 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1251 0.0264 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1798 0.0263 sec/batch
# Nearest to all: niche, unites, thrace, disable, draw, style, generis, remain,
# Nearest to called: protists, cations, transformations, beelzebub, vortex, name, mcdivitt, gobierno,
# Nearest to so: adopt, imbalance, disproving, secreted, multinomial, dispelled, happens, simultaneously,
# Nearest to th: flourished, century, raping, fenwick, side, chrysostom, issachar, eight,
# Nearest to an: thumbnails, formulated, funimation, accorded, lite, farthest, cloudbusting, valuations,
# Nearest to time: fux, this, crowther, turbines, tone, symmetric, continuous, notorious,
# Nearest to may: inelastic, dealerships, starches, cubed, aa, questioner, provoking, discontinuing,
# Nearest to that: segmenting, laparoscopic, harmed, even, stand, they, warmly, secondly,
# Nearest to paris: sylvia, reorganised, heel, predynastic, isaf, watts, cycladic, cesar,
# Nearest to mean: organisms, lambda, xiamen, tells, hostetler, i, climates, lbs,
# Nearest to active: ambients, mri, reinforces, phyla, cryptanalytic, catheter, potsdam, legalistic,
# Nearest to governor: shivaji, wiles, appoints, masonic, joni, devasting, chairman, bill,
# Nearest to pressure: sported, subiaco, constant, agents, rockets, depths, observes, timely,
# Nearest to engine: diesel, propelled, engines, merina, plano, repairing, automobile, piston,
# Nearest to san: courland, manila, landry, bernardi, butte, levy, astros, surfacing,
# Nearest to test: slide, recorders, totowa, haines, alternating, wanderer, forecasted, weasels,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2024 0.0272 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1975 0.0264 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1845 0.0263 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1901 0.0262 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1458 0.0263 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1592 0.0262 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1803 0.0263 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1160 0.0264 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1804 0.0264 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1923 0.0264 sec/batch
# Nearest to all: thrace, niche, unites, disable, generis, style, draw, monegasque,
# Nearest to called: protists, cations, beelzebub, vortex, name, transformations, gobierno, amigabasic,
# Nearest to so: adopt, imbalance, disproving, dispelled, deeply, secreted, happens, bord,
# Nearest to th: flourished, century, raping, eight, fenwick, chrysostom, side, homoousios,
# Nearest to an: thumbnails, accorded, farthest, kossuth, cloudbusting, funimation, spokesman, berzelius,
# Nearest to time: fux, this, crowther, notorious, turbines, tone, kahlert, probing,
# Nearest to may: provoking, inelastic, cubed, questioner, dealerships, ramifications, aa, polygyny,
# Nearest to that: even, harmed, stand, laparoscopic, warmly, hardline, they, segmenting,
# Nearest to paris: reorganised, sylvia, isaf, heel, predynastic, cycladic, cesar, watts,
# Nearest to mean: lambda, tells, xiamen, note, hostetler, organisms, exactly, i,
# Nearest to active: ambients, phyla, mri, potsdam, catheter, reinforces, cryptanalytic, post,
# Nearest to governor: shivaji, wiles, devasting, masonic, worked, bill, joni, saipan,
# Nearest to pressure: subiaco, sported, constant, rockets, depths, observes, exteriors, plunging,
# Nearest to engine: diesel, engines, propelled, merina, piston, repairing, automobile, plano,
# Nearest to san: courland, landry, manila, bernardi, teenager, butte, astros, surfacing,
# Nearest to test: slide, recorders, totowa, forecasted, wanderer, haines, alternating, nanoscale,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2289 0.0271 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1330 0.0263 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1327 0.0262 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1625 0.0262 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0275 0.0263 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1441 0.0263 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1473 0.0264 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1499 0.0263 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1764 0.0046 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1202 0.0262 sec/batch
# Nearest to all: niche, thrace, unites, disable, style, generis, draw, monegasque,
# Nearest to called: protists, cations, beelzebub, name, gobierno, mare, mcdivitt, amigabasic,
# Nearest to so: adopt, dispelled, imbalance, disproving, secreted, multinomial, cassie, simultaneously,
# Nearest to th: flourished, century, raping, fenwick, dates, history, empire, chrysostom,
# Nearest to an: thumbnails, funimation, accorded, farthest, valuations, berzelius, cloudbusting, ro,
# Nearest to time: fux, this, crowther, turbines, probing, continuous, tone, notorious,
# Nearest to may: inelastic, cubed, provoking, starches, aa, dealerships, dip, polygyny,
# Nearest to that: even, laparoscopic, segmenting, harmed, reductions, stand, secondly, shuffles,
# Nearest to paris: reorganised, sylvia, heel, cycladic, isaf, predynastic, cesar, watts,
# Nearest to mean: lambda, note, tells, exactly, hostetler, i, xiamen, organisms,
# Nearest to active: ambients, phyla, mri, reinforces, potsdam, catheter, post, cryptanalytic,
# Nearest to governor: shivaji, wiles, worked, masonic, devasting, joni, saipan, bill,
# Nearest to pressure: subiaco, sported, constant, rockets, exteriors, depths, observes, emergencies,
# Nearest to engine: diesel, engines, propelled, merina, piston, automobile, repairing, automobiles,
# Nearest to san: courland, manila, landry, astros, bernardi, butte, surfacing, teenager,
# Nearest to test: slide, recorders, totowa, forecasted, lankan, seventh, alternating, wanderer,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0607 0.0274 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0623 0.0264 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0660 0.0263 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0480 0.0264 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0728 0.0263 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0339 0.0263 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0906 0.0264 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0896 0.0262 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1074 0.0263 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0519 0.0264 sec/batch
# Nearest to all: niche, thrace, unites, disable, style, draw, monegasque, generis,
# Nearest to called: protists, cations, name, a, beelzebub, vortex, gobierno, hemoglobin,
# Nearest to so: adopt, dispelled, disproving, imbalance, bargain, position, multinomial, cassie,
# Nearest to th: century, flourished, raping, homoousios, dates, history, issachar, fenwick,
# Nearest to an: thumbnails, farthest, accorded, u, valuations, berzelius, ro, funimation,
# Nearest to time: this, crowther, fux, probing, continuous, prover, turbines, twin,
# Nearest to may: inelastic, cubed, aa, dip, dealerships, starches, polygyny, chromic,
# Nearest to that: even, segmenting, laparoscopic, reductions, shuffles, harmed, they, secondly,
# Nearest to paris: cycladic, reorganised, sylvia, heel, yn, de, isaf, watts,
# Nearest to mean: xiamen, note, lambda, tells, hostetler, exactly, i, odham,
# Nearest to active: ambients, mri, reinforces, phyla, catheter, cryptanalytic, potsdam, post,
# Nearest to governor: shivaji, wiles, masonic, belarussian, appointed, ides, devasting, unpopular,
# Nearest to pressure: subiaco, constant, sported, rockets, exteriors, emergencies, depths, observes,
# Nearest to engine: engines, diesel, propelled, automobile, merina, piston, volkswagen, repairing,
# Nearest to san: landry, manila, astros, courland, bernardi, corrie, butte, california,
# Nearest to test: slide, recorders, totowa, forecasted, seventh, lankan, haines, wanderer,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9941 0.0272 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0305 0.0263 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0182 0.0263 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0430 0.0262 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0694 0.0262 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0538 0.0262 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0436 0.0263 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1179 0.0262 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0555 0.0264 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0428 0.0263 sec/batch
# Nearest to all: niche, thrace, unites, draw, generis, style, monegasque, take,
# Nearest to called: protists, a, cations, name, vortex, beelzebub, hemoglobin, transformations,
# Nearest to so: adopt, imbalance, multinomial, dispelled, secreted, disproving, i, casein,
# Nearest to th: century, flourished, raping, fenwick, homoousios, history, therese, dates,
# Nearest to an: thumbnails, farthest, valuations, accorded, ro, objective, accented, berzelius,
# Nearest to time: fux, this, crowther, continuous, probing, prover, cnr, turbines,
# Nearest to may: inelastic, cubed, dealerships, polygyny, aa, starches, religionists, ayckbourn,
# Nearest to that: segmenting, harmed, laparoscopic, secondly, reductions, even, entails, they,
# Nearest to paris: cycladic, de, watts, heel, et, sylvia, reorganised, cesar,
# Nearest to mean: tells, i, xiamen, note, hostetler, lbs, exactly, lambda,
# Nearest to active: ambients, mri, phyla, reinforces, catheter, post, cryptanalytic, potsdam,
# Nearest to governor: shivaji, wiles, masonic, belarussian, pundit, ides, devasting, unpopular,
# Nearest to pressure: subiaco, constant, sported, emergencies, exteriors, observes, rockets, thermodynamics,
# Nearest to engine: engines, diesel, propelled, piston, automobile, merina, volkswagen, repairing,
# Nearest to san: landry, astros, courland, manila, california, butte, corrie, bernardi,
# Nearest to test: slide, recorders, totowa, forecasted, seventh, lankan, wanderer, haines,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0566 0.0271 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1019 0.0264 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0617 0.0264 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0637 0.0263 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0694 0.0263 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0469 0.0263 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0879 0.0262 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0467 0.0264 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0817 0.0263 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0774 0.0264 sec/batch
# Nearest to all: thrace, niche, unites, draw, take, generis, monegasque, style,
# Nearest to called: protists, name, cations, a, gobierno, vortex, beelzebub, mare,
# Nearest to so: adopt, imbalance, multinomial, disproving, dispelled, secreted, revisit, bord,
# Nearest to th: century, flourished, history, raping, dates, homoousios, issachar, fenwick,
# Nearest to an: accorded, thumbnails, farthest, valuations, ro, objective, spokesman, amhr,
# Nearest to time: fux, crowther, this, continuous, castile, prover, yorktown, cnr,
# Nearest to may: inelastic, religionists, ayckbourn, cubed, polygyny, aa, bonner, questioner,
# Nearest to that: harmed, reductions, even, segmenting, hardline, laparoscopic, warmly, repeal,
# Nearest to paris: cycladic, de, et, reorganised, heel, sylvia, french, cesar,
# Nearest to mean: note, tells, lbs, i, xiamen, hostetler, climates, lambda,
# Nearest to active: ambients, reinforces, mri, catheter, potsdam, post, phyla, demanded,
# Nearest to governor: shivaji, wiles, pundit, commons, appointed, belarussian, ides, lags,
# Nearest to pressure: subiaco, constant, sported, observes, exteriors, rockets, emergencies, thermodynamics,
# Nearest to engine: engines, diesel, propelled, piston, merina, automobile, volkswagen, cylinder,
# Nearest to san: landry, courland, astros, butte, manila, francisco, bernardi, cathedrals,
# Nearest to test: slide, totowa, recorders, forecasted, lankan, haines, seventh, ban,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0565 0.0273 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9959 0.0263 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0689 0.0262 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0370 0.0275 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0847 0.0264 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1337 0.0264 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1446 0.0263 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0382 0.0263 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0521 0.0264 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0425 0.0273 sec/batch
# Nearest to all: thrace, draw, niche, unites, take, disable, generis, monegasque,
# Nearest to called: protists, cations, name, a, beelzebub, gobierno, vortex, consists,
# Nearest to so: imbalance, adopt, multinomial, disproving, i, dispelled, sitter, predated,
# Nearest to th: century, flourished, raping, dates, history, homoousios, fenwick, unspectacular,
# Nearest to an: accorded, farthest, thumbnails, ro, objective, valuations, u, berzelius,
# Nearest to time: fux, this, crowther, continuous, kahlert, yorktown, probing, castile,
# Nearest to may: inelastic, ayckbourn, cubed, aa, religionists, bonner, dip, savants,
# Nearest to that: reductions, segmenting, harmed, even, squaring, stand, shuffles, emunah,
# Nearest to paris: de, cycladic, et, heel, reorganised, french, sylvia, prudently,
# Nearest to mean: note, tells, i, lbs, exactly, xiamen, hostetler, climates,
# Nearest to active: ambients, mri, reinforces, catheter, demanded, potsdam, post, phyla,
# Nearest to governor: shivaji, bill, pundit, wiles, commons, ides, appointed, ernie,
# Nearest to pressure: subiaco, constant, sported, rockets, exteriors, emergencies, observes, thermodynamics,
# Nearest to engine: engines, diesel, propelled, piston, merina, cylinder, automobile, murchison,
# Nearest to san: landry, courland, astros, cathedrals, butte, manila, california, bernardi,
# Nearest to test: slide, totowa, lankan, forecasted, recorders, hazardous, seventh, ban,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9908 0.0283 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0151 0.0281 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0193 0.0286 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0185 0.0283 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0654 0.0271 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0505 0.0244 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0147 0.0270 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0011 0.0273 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0188 0.0273 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9565 0.0274 sec/batch
# Nearest to all: thrace, niche, draw, unites, style, generis, into, monegasque,
# Nearest to called: protists, a, cations, name, gobierno, vortex, mare, beelzebub,
# Nearest to so: dispelled, adopt, multinomial, casein, happens, i, disproving, imbalance,
# Nearest to th: century, flourished, dates, raping, history, homoousios, fenwick, therese,
# Nearest to an: farthest, accorded, thumbnails, ro, objective, valuations, u, dreary,
# Nearest to time: fux, this, crowther, yorktown, continuous, probing, kahlert, andhra,
# Nearest to may: inelastic, aa, ayckbourn, religionists, savants, cubed, bonner, dealerships,
# Nearest to that: even, reductions, segmenting, harmed, laparoscopic, waw, squaring, did,
# Nearest to paris: cycladic, de, et, heel, reorganised, watts, french, cesar,
# Nearest to mean: note, tells, lbs, xiamen, hostetler, exactly, odham, qi,
# Nearest to active: ambients, potsdam, reinforces, post, catheter, mri, demanded, vocational,
# Nearest to governor: shivaji, pundit, commons, wiles, ides, pastor, belarussian, ernie,
# Nearest to pressure: subiaco, constant, sported, emergencies, exteriors, rockets, temperature, thermodynamics,
# Nearest to engine: engines, diesel, propelled, piston, automobile, murchison, automotive, cylinder,
# Nearest to san: landry, astros, manila, courland, bernardi, cathedrals, francisco, corrie,
# Nearest to test: slide, lankan, totowa, forecasted, recorders, ban, crucifixion, seventh,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9918 0.0283 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9391 0.0272 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0233 0.0279 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0109 0.0271 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0121 0.0273 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0195 0.0275 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9340 0.0272 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9384 0.0270 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9441 0.0269 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0066 0.0270 sec/batch
# Nearest to all: thrace, niche, unites, draw, take, separation, generis, monegasque,
# Nearest to called: a, protists, cations, name, gobierno, vortex, consists, mare,
# Nearest to so: adopt, multinomial, dispelled, casein, i, molarity, happens, imbalance,
# Nearest to th: century, flourished, dates, homoousios, raping, history, flu, fenwick,
# Nearest to an: accorded, farthest, thumbnails, ro, dreary, u, and, objective,
# Nearest to time: this, crowther, fux, continuous, probing, simultaneous, prover, converting,
# Nearest to may: inelastic, religionists, dealerships, savants, cubed, ayckbourn, aa, dip,
# Nearest to that: reductions, segmenting, even, harmed, laparoscopic, deterrent, glistening, shuffles,
# Nearest to paris: cycladic, de, et, sur, heel, aise, watts, french,
# Nearest to mean: note, lbs, xiamen, tells, qi, climates, hoaxed, exactly,
# Nearest to active: ambients, mri, reinforces, catheter, phyla, post, cryptanalytic, lahaye,
# Nearest to governor: shivaji, commons, pundit, wiles, appointed, unpopular, belarussian, appoints,
# Nearest to pressure: subiaco, constant, thermodynamics, temperature, hospitalization, sported, exteriors, observes,
# Nearest to engine: engines, diesel, piston, propelled, automobile, murchison, automotive, cylinder,
# Nearest to san: francisco, landry, astros, manila, california, courland, corrie, cathedrals,
# Nearest to test: slide, lankan, forecasted, ban, totowa, recorders, hazardous, tests,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0245 0.0284 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0078 0.0275 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9693 0.0273 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0378 0.0273 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0078 0.0273 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9512 0.0275 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9960 0.0274 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9792 0.0274 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9886 0.0273 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9909 0.0269 sec/batch
# Nearest to all: thrace, take, draw, unites, style, into, most, generis,
# Nearest to called: a, protists, name, cations, beelzebub, gobierno, vortex, reflexivity,
# Nearest to so: dispelled, adopt, multinomial, i, omitted, happens, disproving, slasher,
# Nearest to th: century, flourished, raping, dates, homoousios, history, therese, flu,
# Nearest to an: accorded, and, farthest, ro, a, u, foreleg, thumbnails,
# Nearest to time: this, fux, crowther, continuous, cnr, replicants, kahlert, prover,
# Nearest to may: inelastic, religionists, savants, bonner, ayckbourn, aa, dealerships, discontinuing,
# Nearest to that: reductions, even, segmenting, harmed, represent, squaring, waw, deterrent,
# Nearest to paris: cycladic, de, et, sur, aise, french, sylvia, heel,
# Nearest to mean: note, lbs, tells, xiamen, climates, qi, hoaxed, comprehended,
# Nearest to active: ambients, mri, reinforces, catheter, lahaye, potsdam, post, reductions,
# Nearest to governor: shivaji, pundit, appointed, ernie, wiles, lags, commons, devasting,
# Nearest to pressure: constant, subiaco, temperature, hospitalization, sported, thermodynamics, exteriors, observes,
# Nearest to engine: engines, diesel, propelled, piston, automobile, murchison, wankel, chops,
# Nearest to san: landry, francisco, astros, manila, california, courland, corrie, cathedrals,
# Nearest to test: slide, lankan, forecasted, totowa, recorders, ban, tests, hazardous,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9902 0.0280 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9457 0.0271 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9867 0.0273 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9963 0.0273 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0114 0.0275 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0367 0.0275 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9738 0.0276 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9556 0.0273 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9681 0.0274 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9873 0.0273 sec/batch
# Nearest to all: thrace, take, niche, increment, separation, style, unites, most,
# Nearest to called: protists, a, cations, name, gobierno, established, vortex, mare,
# Nearest to so: adopt, multinomial, i, dispelled, omitted, merely, happens, obvious,
# Nearest to th: century, flourished, dates, homoousios, raping, history, flu, historians,
# Nearest to an: accorded, and, a, u, ro, valuations, amhr, foreleg,
# Nearest to time: this, fux, crowther, andhra, continuous, kahlert, cnr, converting,
# Nearest to may: inelastic, religionists, ayckbourn, bonner, cubed, formalities, provoking, figured,
# Nearest to that: reductions, even, harmed, segmenting, deterrent, glistening, quelled, waw,
# Nearest to paris: cycladic, de, heel, sur, et, aise, french, prudently,
# Nearest to mean: note, lbs, tells, qi, xiamen, i, comprehended, hoaxed,
# Nearest to active: ambients, catheter, reinforces, mri, post, demanded, lahaye, reductions,
# Nearest to governor: shivaji, appointed, commons, pundit, appoints, always, bill, wiles,
# Nearest to pressure: subiaco, constant, hospitalization, exteriors, observes, rockets, temperature, sported,
# Nearest to engine: engines, diesel, propelled, piston, automotive, wankel, chops, murchison,
# Nearest to san: francisco, landry, manila, cathedrals, courland, astros, ibiza, nomos,
# Nearest to test: slide, lankan, hazardous, ban, forecasted, totowa, tests, recorders,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9662 0.0284 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0959 0.0276 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0287 0.0270 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0328 0.0272 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9382 0.0270 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9610 0.0272 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 4.0101 0.0274 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9263 0.0275 sec/batch
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8139 0.0271 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8145 0.0268 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8660 0.0269 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8699 0.0267 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8174 0.0266 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8484 0.0265 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9037 0.0266 sec/batch
# Nearest to all: and, their, there, the, are, a, most, not,
# Nearest to called: a, and, the, non, as, which, an, name,
# Nearest to so: omitted, happens, if, it, be, i, find, multinomial,
# Nearest to th: century, dates, nd, birthrate, homoousios, hardcover, dichotomy, eight,
# Nearest to an: and, a, the, to, for, oxidant, as, called,
# Nearest to time: this, even, continuous, simultaneous, only, in, jbls, ever,
# Nearest to may: not, depending, gv, henares, for, empowered, terminally, crossley,
# Nearest to that: even, it, they, the, but, not, a, is,
# Nearest to paris: aise, et, appliqu, sur, volution, opens, unfinished, de,
# Nearest to mean: lbs, note, hoaxed, qi, odham, iris, xiamen, hamelin,
# Nearest to active: hydrogens, lahaye, bergomi, attached, ambients, grunts, competence, reinforces,
# Nearest to governor: appointed, shivaji, pundit, lieutenant, surveyor, upsilon, creeks, hickey,
# Nearest to pressure: exteriors, constant, boost, beers, efficiency, temperature, hospitalization, eccentric,
# Nearest to engine: engines, diesel, wankel, compressor, combustion, throttle, fuel, spark,
# Nearest to san: francisco, california, astros, diego, takings, osvaldo, manila, cathedrals,
# Nearest to test: tests, lankan, conducted, forecasted, wickets, hazardous, slide, kathy,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8222 0.0274 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8362 0.0265 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8450 0.0266 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8649 0.0266 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8726 0.0266 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8876 0.0267 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8748 0.0264 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8813 0.0264 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9014 0.0267 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8230 0.0266 sec/batch
# Nearest to all: and, there, their, the, are, not, most, a,
# Nearest to called: a, and, which, the, non, name, as, this,
# Nearest to so: that, omitted, happens, be, i, adopt, it, multinomial,
# Nearest to th: century, dates, nd, birthrate, homoousios, dichotomy, historians, halevi,
# Nearest to an: a, and, to, the, as, of, from, in,
# Nearest to time: this, was, ever, by, even, spent, crowther, in,
# Nearest to may: henares, not, gv, depending, religionists, for, terminally, empowered,
# Nearest to that: it, even, but, however, the, not, is, they,
# Nearest to paris: aise, et, sur, appliqu, volution, unfinished, de, poitiers,
# Nearest to mean: lbs, note, hoaxed, iris, qi, odham, exactly, hamelin,
# Nearest to active: attached, hydrogens, lahaye, ambients, bergomi, grunts, competence, reinforces,
# Nearest to governor: appointed, shivaji, lieutenant, pundit, surveyor, chief, upsilon, hickey,
# Nearest to pressure: exteriors, constant, temperature, subiaco, hospitalization, observes, efficiency, beers,
# Nearest to engine: engines, diesel, wankel, compressor, combustion, kundalini, throttle, concordat,
# Nearest to san: francisco, astros, california, osvaldo, diego, cathedrals, takings, manila,
# Nearest to test: tests, lankan, forecasted, conducted, wickets, hazardous, ban, aureus,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8718 0.0276 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8529 0.0264 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8271 0.0268 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8365 0.0265 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9121 0.0266 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8350 0.0268 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9482 0.0267 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8803 0.0265 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9369 0.0264 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8184 0.0263 sec/batch
# Nearest to all: and, there, their, with, the, take, a, for,
# Nearest to called: a, non, name, groupoid, and, formerly, which, the,
# Nearest to so: i, omitted, find, happens, obvious, multinomial, adopt, that,
# Nearest to th: century, dates, nd, birthrate, homoousios, historians, dichotomy, halevi,
# Nearest to an: a, and, the, to, in, as, from, of,
# Nearest to time: this, spent, in, was, simultaneous, by, at, duration,
# Nearest to may: henares, gv, not, depending, designate, religionists, terminally, gifs,
# Nearest to that: it, even, the, however, would, been, but, not,
# Nearest to paris: aise, et, sur, appliqu, volution, sorbonne, opens, france,
# Nearest to mean: lbs, note, hoaxed, qi, exactly, iris, odham, hamelin,
# Nearest to active: bergomi, attached, hydrogens, lahaye, demanded, grunts, competence, ambients,
# Nearest to governor: appointed, shivaji, pundit, lieutenant, surveyor, hickey, chief, upsilon,
# Nearest to pressure: exteriors, constant, hospitalization, efficiency, subiaco, temperature, beers, boost,
# Nearest to engine: engines, diesel, wankel, compressor, combustion, kundalini, concordat, compressed,
# Nearest to san: francisco, california, astros, takings, cathedrals, osvaldo, analogues, diego,
# Nearest to test: tests, lankan, conducted, forecasted, wickets, hazardous, kathy, ban,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7771 0.0270 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8762 0.0262 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7778 0.0263 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8882 0.0264 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8492 0.0263 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8528 0.0263 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9226 0.0130 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8607 0.0263 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8373 0.0262 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8218 0.0267 sec/batch
# Nearest to all: and, their, there, the, with, not, are, furies,
# Nearest to called: a, non, and, name, as, formerly, an, which,
# Nearest to so: omitted, i, it, find, be, concubine, obvious, that,
# Nearest to th: century, dates, homoousios, nd, historians, birthrate, dichotomy, listing,
# Nearest to an: a, and, the, to, in, as, from, of,
# Nearest to time: this, spent, was, at, duration, quelled, in, simultaneous,
# Nearest to may: henares, gv, terminally, depending, april, suppers, caspases, crossley,
# Nearest to that: it, the, even, to, but, been, they, however,
# Nearest to paris: aise, et, appliqu, volution, sur, sorbonne, opens, poitiers,
# Nearest to mean: lbs, note, hoaxed, qi, hamelin, exactly, odham, weighted,
# Nearest to active: bergomi, attached, lahaye, hydrogens, competence, ambients, demanded, vocational,
# Nearest to governor: shivaji, lieutenant, appointed, pundit, surveyor, hickey, upsilon, creep,
# Nearest to pressure: exteriors, constant, temperature, hospitalization, efficiency, beers, trilled, subiaco,
# Nearest to engine: engines, diesel, wankel, compressor, concordat, kundalini, compressed, combustion,
# Nearest to san: francisco, astros, california, takings, jose, osvaldo, cathedrals, diego,
# Nearest to test: tests, lankan, conducted, wickets, forecasted, aureus, kathy, hazardous,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8324 0.0280 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8271 0.0267 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8187 0.0265 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7816 0.0266 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8502 0.0262 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8335 0.0266 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8623 0.0267 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7731 0.0263 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8158 0.0262 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8076 0.0263 sec/batch
# Nearest to all: and, there, their, the, with, in, a, are,
# Nearest to called: a, and, an, the, is, which, this, non,
# Nearest to so: omitted, multinomial, i, if, happens, find, hobbled, casein,
# Nearest to th: century, dates, birthrate, homoousios, dichotomy, historians, nd, hardcover,
# Nearest to an: a, and, the, to, as, of, from, called,
# Nearest to time: this, at, even, only, in, duration, ever, factorizations,
# Nearest to may: depending, not, gv, henares, empowered, are, all, have,
# Nearest to that: it, even, the, is, to, been, a, they,
# Nearest to paris: aise, et, volution, appliqu, sur, france, opens, poitiers,
# Nearest to mean: lbs, note, hoaxed, odham, qi, hamelin, iris, weighted,
# Nearest to active: attached, bergomi, ambients, competence, lahaye, organized, hydrogens, grunts,
# Nearest to governor: appointed, shivaji, lieutenant, pundit, surveyor, upsilon, chief, creep,
# Nearest to pressure: exteriors, constant, temperature, beers, efficiency, boost, hospitalization, trilled,
# Nearest to engine: engines, diesel, wankel, compressor, murchison, kundalini, secretary, automakers,
# Nearest to san: francisco, california, jose, takings, astros, diego, los, osvaldo,
# Nearest to test: tests, lankan, conducted, wickets, kathy, forecasted, hazardous, aureus,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7600 0.0271 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8253 0.0263 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8582 0.0264 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7901 0.0264 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7853 0.0264 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9084 0.0266 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8316 0.0265 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8064 0.0263 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8230 0.0265 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8396 0.0266 sec/batch
# Nearest to all: and, there, their, the, a, in, are, with,
# Nearest to called: a, the, and, which, this, name, of, as,
# Nearest to so: omitted, find, it, if, happens, be, i, multinomial,
# Nearest to th: century, dates, birthrate, nd, homoousios, dichotomy, historians, birthday,
# Nearest to an: a, and, the, to, as, of, for, from,
# Nearest to time: this, even, spent, at, duration, ever, seconds, crowther,
# Nearest to may: depending, have, religionists, not, henares, terminally, to, all,
# Nearest to that: it, even, the, to, but, been, they, not,
# Nearest to paris: aise, et, appliqu, volution, sur, france, french, poitiers,
# Nearest to mean: lbs, hoaxed, note, qi, ericaceae, hamelin, iris, odham,
# Nearest to active: attached, lahaye, hydrogens, reinforces, ambients, competence, bergomi, grunts,
# Nearest to governor: appointed, shivaji, pundit, surveyor, lieutenant, upsilon, hickey, creep,
# Nearest to pressure: exteriors, constant, temperature, beers, boost, hospitalization, efficiency, eccentric,
# Nearest to engine: engines, diesel, wankel, compressor, kundalini, combustion, compressed, throttle,
# Nearest to san: francisco, california, astros, diego, takings, jose, los, osvaldo,
# Nearest to test: tests, conducted, lankan, forecasted, kathy, wickets, aureus, hazardous,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8891 0.0271 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8311 0.0263 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8157 0.0264 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8463 0.0264 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8810 0.0262 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8518 0.0265 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8218 0.0264 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8332 0.0263 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8232 0.0263 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8171 0.0262 sec/batch
# Nearest to all: and, there, their, for, not, in, with, the,
# Nearest to called: a, and, the, which, this, of, an, non,
# Nearest to so: omitted, be, find, i, if, happens, multinomial, obvious,
# Nearest to th: century, birthrate, dates, historians, dichotomy, homoousios, nd, hardcover,
# Nearest to an: a, and, the, to, of, as, in, called,
# Nearest to time: this, was, even, simultaneous, only, by, duration, in,
# Nearest to may: depending, have, not, of, patterns, are, henares, religionists,
# Nearest to that: it, even, the, been, not, but, however, to,
# Nearest to paris: aise, appliqu, volution, et, sur, opens, sorbonne, french,
# Nearest to mean: lbs, note, hoaxed, qi, odham, ericaceae, weighted, iris,
# Nearest to active: hydrogens, attached, lahaye, bergomi, organized, competence, reinforces, grunts,
# Nearest to governor: appointed, surveyor, shivaji, lieutenant, pundit, upsilon, hickey, chief,
# Nearest to pressure: exteriors, constant, temperature, beers, hospitalization, efficiency, boost, eccentric,
# Nearest to engine: engines, diesel, wankel, compressor, combustion, gasoline, throttle, compressed,
# Nearest to san: francisco, takings, diego, california, astros, jose, cathedrals, osvaldo,
# Nearest to test: tests, conducted, lankan, forecasted, kathy, aureus, hazardous, wickets,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8676 0.0271 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8053 0.0267 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9009 0.0267 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9327 0.0263 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8795 0.0265 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8448 0.0265 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8308 0.0265 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8203 0.0267 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7484 0.0263 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8293 0.0266 sec/batch
# Nearest to all: and, there, their, in, for, are, with, can,
# Nearest to called: a, and, non, which, is, this, an, of,
# Nearest to so: happens, be, find, it, omitted, if, isn, multinomial,
# Nearest to th: century, dates, birthrate, nd, dichotomy, historians, hardcover, homoousios,
# Nearest to an: a, and, the, to, of, in, as, from,
# Nearest to time: this, was, spent, simultaneous, composing, duration, even, in,
# Nearest to may: depending, terminally, not, all, gv, designate, are, foobar,
# Nearest to that: it, even, been, to, the, however, not, but,
# Nearest to paris: aise, appliqu, et, opens, volution, france, sur, poitiers,
# Nearest to mean: lbs, note, hoaxed, exactly, qi, weighted, odham, iris,
# Nearest to active: attached, hydrogens, bergomi, lahaye, grunts, demanded, ambients, competence,
# Nearest to governor: appointed, surveyor, shivaji, lieutenant, pundit, hickey, upsilon, chief,
# Nearest to pressure: exteriors, constant, temperature, hospitalization, beers, efficiency, boost, overboard,
# Nearest to engine: engines, diesel, compressor, wankel, combustion, throttle, gasoline, automotive,
# Nearest to san: francisco, california, takings, diego, jose, astros, oakland, cathedrals,
# Nearest to test: tests, lankan, conducted, forecasted, hazardous, kathy, aureus, wickets,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8564 0.0272 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8227 0.0263 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
